# %% [markdown]
# Ethereum Historical dataset
# ```
# (https://finance.yahoo.com/quote/ETH-USD/?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAAHhBLSY1-QzWHStroNBQEIpa7cMFcsdlrSjp_zRbkbQlzrXw6cmAJHJz7JolkH-1dBgNV692giH_MWKeNMyRC7XKk98hHUa9v5RZ9H81ldNzTEYIWfl6peqUO-7583tpbW4jlXEV2VYVOBX2DfTundpK1beChrX_aqLrTHQ6tNOu)
# ```

# %% [markdown]
# Sentiment Analysis dataset
# ```
# (https://en.wikipedia.org/wiki/Ethereum)
# ```

# %%
# Installing  Libraries
# !pip install mwclient
# !pip install torch torchvision torchaudio
# !pip install statistics
# Out:
# Requirement already satisfied: mwclient in c:\users\sanja\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: requests-oauthlib in c:\users\sanja\anaconda3\lib\site-packages (from mwclient) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sanja\anaconda3\lib\site-packages (from requests-oauthlib->mwclient) (3.3.1)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sanja\anaconda3\lib\site-packages (from requests-oauthlib->mwclient) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sanja\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib->mwclient) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sanja\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib->mwclient) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sanja\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib->mwclient) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sanja\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib->mwclient) (2024.8.30)
# Requirement already satisfied: torch in c:\users\sanja\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: torchvision in c:\users\sanja\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: torchaudio in c:\users\sanja\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: filelock in c:\users\sanja\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sanja\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in c:\users\sanja\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\sanja\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\sanja\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\sanja\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\sanja\anaconda3\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sanja\anaconda3\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\sanja\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\sanja\anaconda3\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sanja\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: statistics in c:\users\sanja\anaconda3\lib\site-packages (1.0.3.5)
# Requirement already satisfied: docutils>=0.3 in c:\users\sanja\anaconda3\lib\site-packages (from statistics) (0.18.1)

# %%
# Importing Libraries
import mwclient
import time
import pandas as pd
import torch
from transformers import pipeline
from statistics import mean
from datetime import datetime
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score
from xgboost import XGBClassifier
import yfinance as yf
import os
import pandas as pd
site = mwclient.Site("en.Wikipedia.org")
page = site.pages["Ethereum"]

# %%
# Get a list of revisions
revs = list(page.revisions())

# %%
revs[0]
# Out:
# OrderedDict([('revid', 1311515079),
#              ('parentid', 1311514717),
#              ('user', 'SolVesc'),
#              ('timestamp',
#               time.struct_time(tm_year=2025, tm_mon=9, tm_mday=15, tm_hour=14, tm_min=30, tm_sec=50, tm_wday=0, tm_yday=258, tm_isdst=-1)),
#              ('comment', '')])

# %%
revs = sorted(revs, key=lambda rev: rev["timestamp"])

# %%
revs[0]
# Out:
# OrderedDict([('revid', 592567939),
#              ('parentid', 0),
#              ('user', 'Sanpitch'),
#              ('timestamp',
#               time.struct_time(tm_year=2014, tm_mon=1, tm_mday=27, tm_hour=1, tm_min=53, tm_sec=45, tm_wday=0, tm_yday=27, tm_isdst=-1)),
#              ('comment',
#               "[[WP:AES|←]]Created page with '{{Infobox currency | image_1 =  | image_title_1 =  | image_width_1 =  | image_2 =  | image_title_2 =  | image_width_2 =  |issuing_authority = None. The Ethereum...'")])

# %%
# Analyzing the sentiment
sentiment_pipeline = pipeline("sentiment-analysis")

def find_sentiment(text):
    sent = sentiment_pipeline([text[:250]])[0]
    score = sent["score"]
    if sent["label"] == "NEGATIVE":
        score *= -1
    return score
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
edits = {}

#converting date into string format from a named tuple
for rev in revs:
  date = time.strftime("%Y-%m-%d", rev["timestamp"])

  if date not in edits:
    edits[date] = dict(sentiments=list(), edit_count=0)

  edits[date]["edit_count"] += 1
  comment = rev.get("comment", "")
  edits[date]["sentiments"].append(find_sentiment(comment))

# %%
from statistics import mean
# Calculating Sentiment score and Negative Sentiment score
for key in edits:
  if len(edits[key]["sentiments"]) > 0:
    edits[key]["sentiment"] = mean(edits[key]["sentiments"])
    edits[key]["neg_sentiment"] = len([s for s in edits[key]["sentiments"] if s < 0]) / len(edits[key]["sentiments"])
  else:
    edits[key]["sentiment"] = 0
    edits[key]["neg_sentiment"] = 0

  del edits[key]["sentiments"]

# %%
edits
# Out:
# {'2014-01-27': {'edit_count': 1,
#   'sentiment': -0.9985105395317078,
#   'neg_sentiment': 1.0},
#  '2014-02-01': {'edit_count': 1,
#   'sentiment': -0.997276246547699,
#   'neg_sentiment': 1.0},
#  '2014-04-06': {'edit_count': 5,
#   'sentiment': 0.7909794330596924,
#   'neg_sentiment': 0.0},
#  '2014-04-09': {'edit_count': 24,
#   'sentiment': 0.646406963467598,
#   'neg_sentiment': 0.08333333333333333},
#  '2014-04-10': {'edit_count': 9,
#   'sentiment': -0.36151769426133895,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-04-11': {'edit_count': 10,
#   'sentiment': 0.5150127589702607,
#   'neg_sentiment': 0.2},
#  '2014-04-12': {'edit_count': 2,
#   'sentiment': -0.04391053318977356,
#   'neg_sentiment': 0.5},
#  '2014-04-13': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-04-17': {'edit_count': 9,
#   'sentiment': 0.30852225091722274,
#   'neg_sentiment': 0.3333333333333333},
#  '2014-04-18': {'edit_count': 1,
#   'sentiment': 0.9109594821929932,
#   'neg_sentiment': 0.0},
#  '2014-04-24': {'edit_count': 2,
#   'sentiment': 0.9975883960723877,
#   'neg_sentiment': 0.0},
#  '2014-04-28': {'edit_count': 1,
#   'sentiment': -0.9362576007843018,
#   'neg_sentiment': 1.0},
#  '2014-06-01': {'edit_count': 1,
#   'sentiment': 0.9758297204971313,
#   'neg_sentiment': 0.0},
#  '2014-06-10': {'edit_count': 1,
#   'sentiment': 0.999515175819397,
#   'neg_sentiment': 0.0},
#  '2014-06-29': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-07-01': {'edit_count': 1,
#   'sentiment': 0.8725757598876953,
#   'neg_sentiment': 0.0},
#  '2014-07-27': {'edit_count': 1,
#   'sentiment': 0.9975883960723877,
#   'neg_sentiment': 0.0},
#  '2014-07-28': {'edit_count': 7,
#   'sentiment': 0.09810128382274083,
#   'neg_sentiment': 0.42857142857142855},
#  '2014-07-29': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-08-03': {'edit_count': 1,
#   'sentiment': -0.9881350994110107,
#   'neg_sentiment': 1.0},
#  '2014-08-06': {'edit_count': 1,
#   'sentiment': -0.8130711317062378,
#   'neg_sentiment': 1.0},
#  '2014-08-10': {'edit_count': 3,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-08-11': {'edit_count': 4,
#   'sentiment': 0.411981001496315,
#   'neg_sentiment': 0.25},
#  '2014-08-12': {'edit_count': 3,
#   'sentiment': -0.4160489837328593,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-08-14': {'edit_count': 2,
#   'sentiment': -0.9828211069107056,
#   'neg_sentiment': 1.0},
#  '2014-08-24': {'edit_count': 1,
#   'sentiment': 0.994047999382019,
#   'neg_sentiment': 0.0},
#  '2014-08-27': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2014-09-03': {'edit_count': 10,
#   'sentiment': 0.5592141270637512,
#   'neg_sentiment': 0.2},
#  '2014-09-04': {'edit_count': 3,
#   'sentiment': 0.24925309419631958,
#   'neg_sentiment': 0.3333333333333333},
#  '2014-09-08': {'edit_count': 1,
#   'sentiment': -0.9565960764884949,
#   'neg_sentiment': 1.0},
#  '2014-09-30': {'edit_count': 1,
#   'sentiment': 0.9787663221359253,
#   'neg_sentiment': 0.0},
#  '2014-10-08': {'edit_count': 2,
#   'sentiment': 0.8621626794338226,
#   'neg_sentiment': 0.0},
#  '2014-10-14': {'edit_count': 2,
#   'sentiment': -0.00965312123298645,
#   'neg_sentiment': 0.5},
#  '2014-10-23': {'edit_count': 4,
#   'sentiment': -0.0022448450326919556,
#   'neg_sentiment': 0.5},
#  '2014-11-13': {'edit_count': 1,
#   'sentiment': 0.9975883960723877,
#   'neg_sentiment': 0.0},
#  '2014-11-23': {'edit_count': 1,
#   'sentiment': 0.9984303116798401,
#   'neg_sentiment': 0.0},
#  '2014-12-08': {'edit_count': 5,
#   'sentiment': 0.8743554353713989,
#   'neg_sentiment': 0.0},
#  '2014-12-14': {'edit_count': 1,
#   'sentiment': 0.9300208687782288,
#   'neg_sentiment': 0.0},
#  '2014-12-17': {'edit_count': 1,
#   'sentiment': -0.9702252149581909,
#   'neg_sentiment': 1.0},
#  '2014-12-19': {'edit_count': 8,
#   'sentiment': 0.6857525035738945,
#   'neg_sentiment': 0.125},
#  '2014-12-20': {'edit_count': 1,
#   'sentiment': -0.9990710020065308,
#   'neg_sentiment': 1.0},
#  '2014-12-23': {'edit_count': 1,
#   'sentiment': -0.9980879426002502,
#   'neg_sentiment': 1.0},
#  '2014-12-27': {'edit_count': 2,
#   'sentiment': -0.000496983528137207,
#   'neg_sentiment': 0.5},
#  '2015-01-05': {'edit_count': 1,
#   'sentiment': -0.9986577033996582,
#   'neg_sentiment': 1.0},
#  '2015-01-10': {'edit_count': 2,
#   'sentiment': 0.9256414473056793,
#   'neg_sentiment': 0.0},
#  '2015-01-15': {'edit_count': 4,
#   'sentiment': 0.7814877182245255,
#   'neg_sentiment': 0.0},
#  '2015-01-16': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2015-01-26': {'edit_count': 1,
#   'sentiment': 0.9109594821929932,
#   'neg_sentiment': 0.0},
#  '2015-01-30': {'edit_count': 1,
#   'sentiment': 0.9929959177970886,
#   'neg_sentiment': 0.0},
#  '2015-02-04': {'edit_count': 1,
#   'sentiment': 0.8428608775138855,
#   'neg_sentiment': 0.0},
#  '2015-02-12': {'edit_count': 1,
#   'sentiment': 0.8548067808151245,
#   'neg_sentiment': 0.0},
#  '2015-02-13': {'edit_count': 1,
#   'sentiment': -0.8406323194503784,
#   'neg_sentiment': 1.0},
#  '2015-02-16': {'edit_count': 3,
#   'sentiment': -0.8955994645754496,
#   'neg_sentiment': 1.0},
#  '2015-02-17': {'edit_count': 1,
#   'sentiment': -0.979144275188446,
#   'neg_sentiment': 1.0},
#  '2015-02-19': {'edit_count': 3,
#   'sentiment': -0.4154774745305379,
#   'neg_sentiment': 0.6666666666666666},
#  '2015-02-20': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2015-02-21': {'edit_count': 2,
#   'sentiment': -0.9989575445652008,
#   'neg_sentiment': 1.0},
#  '2015-03-18': {'edit_count': 1,
#   'sentiment': 0.9975903034210205,
#   'neg_sentiment': 0.0},
#  '2015-03-21': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2015-03-22': {'edit_count': 1,
#   'sentiment': -0.9968094229698181,
#   'neg_sentiment': 1.0},
#  '2015-03-26': {'edit_count': 1,
#   'sentiment': -0.9994649291038513,
#   'neg_sentiment': 1.0},
#  '2015-03-31': {'edit_count': 3,
#   'sentiment': -0.28288282950719196,
#   'neg_sentiment': 0.6666666666666666},
#  '2015-04-09': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2015-04-20': {'edit_count': 1,
#   'sentiment': 0.9435799717903137,
#   'neg_sentiment': 0.0},
#  '2015-04-24': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2015-05-09': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2015-05-17': {'edit_count': 1,
#   'sentiment': 0.8466591238975525,
#   'neg_sentiment': 0.0},
#  '2015-05-24': {'edit_count': 1,
#   'sentiment': 0.996212363243103,
#   'neg_sentiment': 0.0},
#  '2015-05-26': {'edit_count': 1,
#   'sentiment': 0.9866401553153992,
#   'neg_sentiment': 0.0},
#  '2015-05-30': {'edit_count': 1,
#   'sentiment': 0.9959832429885864,
#   'neg_sentiment': 0.0},
#  '2015-06-08': {'edit_count': 1,
#   'sentiment': 0.977993905544281,
#   'neg_sentiment': 0.0},
#  '2015-06-26': {'edit_count': 2,
#   'sentiment': 0.008801639080047607,
#   'neg_sentiment': 0.5},
#  '2015-07-18': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2015-07-22': {'edit_count': 1,
#   'sentiment': -0.8920962810516357,
#   'neg_sentiment': 1.0},
#  '2015-07-23': {'edit_count': 1,
#   'sentiment': 0.9354425072669983,
#   'neg_sentiment': 0.0},
#  '2015-07-25': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2015-07-26': {'edit_count': 2,
#   'sentiment': -0.9177611172199249,
#   'neg_sentiment': 1.0},
#  '2015-07-27': {'edit_count': 1,
#   'sentiment': -0.9994345307350159,
#   'neg_sentiment': 1.0},
#  '2015-07-29': {'edit_count': 3,
#   'sentiment': -0.41034523646036786,
#   'neg_sentiment': 0.6666666666666666},
#  '2015-07-30': {'edit_count': 6,
#   'sentiment': 0.3006567756334941,
#   'neg_sentiment': 0.3333333333333333},
#  '2015-07-31': {'edit_count': 2,
#   'sentiment': 0.843593567609787,
#   'neg_sentiment': 0.0},
#  '2015-08-01': {'edit_count': 2,
#   'sentiment': -0.00036767125129699707,
#   'neg_sentiment': 0.5},
#  '2015-08-02': {'edit_count': 2,
#   'sentiment': -0.07246798276901245,
#   'neg_sentiment': 0.5},
#  '2015-08-04': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2015-08-05': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2015-08-06': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2015-08-07': {'edit_count': 2,
#   'sentiment': 0.7570405304431915,
#   'neg_sentiment': 0.0},
#  '2015-08-09': {'edit_count': 6,
#   'sentiment': -0.650885671377182,
#   'neg_sentiment': 0.8333333333333334},
#  '2015-08-10': {'edit_count': 7,
#   'sentiment': -0.4280558228492737,
#   'neg_sentiment': 0.7142857142857143},
#  '2015-08-13': {'edit_count': 1,
#   'sentiment': 0.8661131262779236,
#   'neg_sentiment': 0.0},
#  '2015-08-14': {'edit_count': 2,
#   'sentiment': -0.12547695636749268,
#   'neg_sentiment': 0.5},
#  '2015-08-21': {'edit_count': 1,
#   'sentiment': 0.9972445964813232,
#   'neg_sentiment': 0.0},
#  '2015-08-22': {'edit_count': 1,
#   'sentiment': -0.9982075691223145,
#   'neg_sentiment': 1.0},
#  '2015-08-28': {'edit_count': 2,
#   'sentiment': 0.9710939824581146,
#   'neg_sentiment': 0.0},
#  '2015-08-30': {'edit_count': 1,
#   'sentiment': -0.9667150378227234,
#   'neg_sentiment': 1.0},
#  '2015-09-07': {'edit_count': 5,
#   'sentiment': -0.9685040593147278,
#   'neg_sentiment': 1.0},
#  '2015-09-13': {'edit_count': 1,
#   'sentiment': -0.996834933757782,
#   'neg_sentiment': 1.0},
#  '2015-09-18': {'edit_count': 1,
#   'sentiment': 0.9749864339828491,
#   'neg_sentiment': 0.0},
#  '2015-09-20': {'edit_count': 1,
#   'sentiment': -0.9939032196998596,
#   'neg_sentiment': 1.0},
#  '2015-09-22': {'edit_count': 1,
#   'sentiment': 0.9972445964813232,
#   'neg_sentiment': 0.0},
#  '2015-09-23': {'edit_count': 2,
#   'sentiment': -0.12565460801124573,
#   'neg_sentiment': 0.5},
#  '2015-09-24': {'edit_count': 1,
#   'sentiment': -0.9962469935417175,
#   'neg_sentiment': 1.0},
#  '2015-09-25': {'edit_count': 1,
#   'sentiment': 0.9749864339828491,
#   'neg_sentiment': 0.0},
#  '2015-09-28': {'edit_count': 1,
#   'sentiment': 0.977993905544281,
#   'neg_sentiment': 0.0},
#  '2015-09-29': {'edit_count': 4,
#   'sentiment': -0.47564220428466797,
#   'neg_sentiment': 0.75},
#  '2015-09-30': {'edit_count': 1,
#   'sentiment': 0.9918097853660583,
#   'neg_sentiment': 0.0},
#  '2015-10-03': {'edit_count': 4,
#   'sentiment': 0.42909201979637146,
#   'neg_sentiment': 0.25},
#  '2015-10-13': {'edit_count': 2,
#   'sentiment': -0.9952731728553772,
#   'neg_sentiment': 1.0},
#  '2015-10-22': {'edit_count': 2,
#   'sentiment': -0.028130829334259033,
#   'neg_sentiment': 0.5},
#  '2015-11-05': {'edit_count': 2,
#   'sentiment': 0.916404664516449,
#   'neg_sentiment': 0.0},
#  '2015-11-06': {'edit_count': 8,
#   'sentiment': -0.06382666528224945,
#   'neg_sentiment': 0.5},
#  '2015-11-13': {'edit_count': 1,
#   'sentiment': -0.9893608689308167,
#   'neg_sentiment': 1.0},
#  '2015-11-20': {'edit_count': 3,
#   'sentiment': 0.2425894339879354,
#   'neg_sentiment': 0.3333333333333333},
#  '2015-11-24': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2015-11-26': {'edit_count': 3,
#   'sentiment': -0.993152936299642,
#   'neg_sentiment': 1.0},
#  '2015-11-30': {'edit_count': 15,
#   'sentiment': 0.011517179012298585,
#   'neg_sentiment': 0.4666666666666667},
#  '2015-12-11': {'edit_count': 3,
#   'sentiment': -0.29907065629959106,
#   'neg_sentiment': 0.6666666666666666},
#  '2015-12-16': {'edit_count': 1,
#   'sentiment': 0.9107902646064758,
#   'neg_sentiment': 0.0},
#  '2015-12-18': {'edit_count': 3,
#   'sentiment': -0.9945226907730103,
#   'neg_sentiment': 1.0},
#  '2015-12-19': {'edit_count': 4,
#   'sentiment': -0.11695535480976105,
#   'neg_sentiment': 0.5},
#  '2015-12-27': {'edit_count': 2,
#   'sentiment': 0.9926086962223053,
#   'neg_sentiment': 0.0},
#  '2015-12-28': {'edit_count': 6,
#   'sentiment': -0.23435717821121216,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-01-09': {'edit_count': 1,
#   'sentiment': -0.8130711317062378,
#   'neg_sentiment': 1.0},
#  '2016-01-16': {'edit_count': 4,
#   'sentiment': -0.5624943226575851,
#   'neg_sentiment': 0.75},
#  '2016-01-17': {'edit_count': 1,
#   'sentiment': -0.9994869232177734,
#   'neg_sentiment': 1.0},
#  '2016-01-28': {'edit_count': 2,
#   'sentiment': -0.033473074436187744,
#   'neg_sentiment': 0.5},
#  '2016-02-04': {'edit_count': 2,
#   'sentiment': -0.03454625606536865,
#   'neg_sentiment': 0.5},
#  '2016-02-08': {'edit_count': 2,
#   'sentiment': -0.12441897392272949,
#   'neg_sentiment': 0.5},
#  '2016-02-10': {'edit_count': 1,
#   'sentiment': -0.9975160360336304,
#   'neg_sentiment': 1.0},
#  '2016-02-16': {'edit_count': 2,
#   'sentiment': -0.9869515597820282,
#   'neg_sentiment': 1.0},
#  '2016-02-17': {'edit_count': 13,
#   'sentiment': -0.38913050523171056,
#   'neg_sentiment': 0.6923076923076923},
#  '2016-02-19': {'edit_count': 4,
#   'sentiment': -0.5958842188119888,
#   'neg_sentiment': 0.75},
#  '2016-02-20': {'edit_count': 12,
#   'sentiment': -0.825177530447642,
#   'neg_sentiment': 0.9166666666666666},
#  '2016-02-21': {'edit_count': 3,
#   'sentiment': -0.9442013303438822,
#   'neg_sentiment': 1.0},
#  '2016-02-22': {'edit_count': 4,
#   'sentiment': 0.4315732568502426,
#   'neg_sentiment': 0.25},
#  '2016-02-23': {'edit_count': 15,
#   'sentiment': -0.3568953553835551,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-02-24': {'edit_count': 2,
#   'sentiment': -0.9991590976715088,
#   'neg_sentiment': 1.0},
#  '2016-02-25': {'edit_count': 2,
#   'sentiment': -0.1258261501789093,
#   'neg_sentiment': 0.5},
#  '2016-02-26': {'edit_count': 3,
#   'sentiment': -0.2956438461939494,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-02-28': {'edit_count': 2,
#   'sentiment': 0.04569658637046814,
#   'neg_sentiment': 0.5},
#  '2016-03-02': {'edit_count': 4,
#   'sentiment': 0.3119249790906906,
#   'neg_sentiment': 0.25},
#  '2016-03-03': {'edit_count': 2,
#   'sentiment': 0.9779015779495239,
#   'neg_sentiment': 0.0},
#  '2016-03-04': {'edit_count': 1,
#   'sentiment': -0.999438464641571,
#   'neg_sentiment': 1.0},
#  '2016-03-05': {'edit_count': 7,
#   'sentiment': 0.49891914640154156,
#   'neg_sentiment': 0.14285714285714285},
#  '2016-03-08': {'edit_count': 1,
#   'sentiment': 0.9624135494232178,
#   'neg_sentiment': 0.0},
#  '2016-03-11': {'edit_count': 3,
#   'sentiment': -0.29210712512334186,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-03-13': {'edit_count': 5,
#   'sentiment': 0.16214557886123657,
#   'neg_sentiment': 0.4},
#  '2016-03-14': {'edit_count': 1,
#   'sentiment': -0.991378664970398,
#   'neg_sentiment': 1.0},
#  '2016-03-16': {'edit_count': 2,
#   'sentiment': -0.9629538357257843,
#   'neg_sentiment': 1.0},
#  '2016-03-18': {'edit_count': 1,
#   'sentiment': -0.9918463826179504,
#   'neg_sentiment': 1.0},
#  '2016-03-20': {'edit_count': 21,
#   'sentiment': -0.5020367190951392,
#   'neg_sentiment': 0.7619047619047619},
#  '2016-03-21': {'edit_count': 40,
#   'sentiment': -0.3694640532135963,
#   'neg_sentiment': 0.675},
#  '2016-03-22': {'edit_count': 10,
#   'sentiment': -0.5923540592193604,
#   'neg_sentiment': 0.8},
#  '2016-03-23': {'edit_count': 10,
#   'sentiment': 0.08717644214630127,
#   'neg_sentiment': 0.4},
#  '2016-03-24': {'edit_count': 4,
#   'sentiment': -0.9901746213436127,
#   'neg_sentiment': 1.0},
#  '2016-03-27': {'edit_count': 2,
#   'sentiment': -0.9921592473983765,
#   'neg_sentiment': 1.0},
#  '2016-03-28': {'edit_count': 3,
#   'sentiment': 0.2421597441037496,
#   'neg_sentiment': 0.3333333333333333},
#  '2016-03-30': {'edit_count': 3,
#   'sentiment': -0.4054137070973714,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-03-31': {'edit_count': 2,
#   'sentiment': -0.9718243777751923,
#   'neg_sentiment': 1.0},
#  '2016-04-01': {'edit_count': 7,
#   'sentiment': 0.032408526965550015,
#   'neg_sentiment': 0.42857142857142855},
#  '2016-04-02': {'edit_count': 1,
#   'sentiment': -0.9990082383155823,
#   'neg_sentiment': 1.0},
#  '2016-04-03': {'edit_count': 1,
#   'sentiment': -0.9988908171653748,
#   'neg_sentiment': 1.0},
#  '2016-04-04': {'edit_count': 4,
#   'sentiment': -0.9733887761831284,
#   'neg_sentiment': 1.0},
#  '2016-04-05': {'edit_count': 5,
#   'sentiment': -0.9153292536735534,
#   'neg_sentiment': 1.0},
#  '2016-04-06': {'edit_count': 1,
#   'sentiment': 0.9597511291503906,
#   'neg_sentiment': 0.0},
#  '2016-04-11': {'edit_count': 5,
#   'sentiment': -0.21092983484268188,
#   'neg_sentiment': 0.6},
#  '2016-04-12': {'edit_count': 5,
#   'sentiment': -0.23031275272369384,
#   'neg_sentiment': 0.6},
#  '2016-04-13': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2016-04-15': {'edit_count': 3,
#   'sentiment': -0.9992120265960693,
#   'neg_sentiment': 1.0},
#  '2016-04-16': {'edit_count': 1,
#   'sentiment': 0.977993905544281,
#   'neg_sentiment': 0.0},
#  '2016-04-18': {'edit_count': 4,
#   'sentiment': -0.9937609434127808,
#   'neg_sentiment': 1.0},
#  '2016-04-19': {'edit_count': 3,
#   'sentiment': -0.3318175474802653,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-04-20': {'edit_count': 4,
#   'sentiment': -0.9134910702705383,
#   'neg_sentiment': 1.0},
#  '2016-04-21': {'edit_count': 3,
#   'sentiment': 0.31961627801259357,
#   'neg_sentiment': 0.3333333333333333},
#  '2016-04-23': {'edit_count': 5,
#   'sentiment': 0.12402303218841552,
#   'neg_sentiment': 0.4},
#  '2016-04-24': {'edit_count': 7,
#   'sentiment': -0.4637776953833444,
#   'neg_sentiment': 0.7142857142857143},
#  '2016-04-25': {'edit_count': 9,
#   'sentiment': 0.05593369404474894,
#   'neg_sentiment': 0.4444444444444444},
#  '2016-04-27': {'edit_count': 3,
#   'sentiment': 0.4000283479690552,
#   'neg_sentiment': 0.3333333333333333},
#  '2016-04-28': {'edit_count': 21,
#   'sentiment': -0.2509687344233195,
#   'neg_sentiment': 0.6190476190476191},
#  '2016-04-29': {'edit_count': 6,
#   'sentiment': -0.3377881745497386,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-05-01': {'edit_count': 7,
#   'sentiment': -0.41658278022493633,
#   'neg_sentiment': 0.7142857142857143},
#  '2016-05-02': {'edit_count': 1,
#   'sentiment': 0.9633464217185974,
#   'neg_sentiment': 0.0},
#  '2016-05-03': {'edit_count': 14,
#   'sentiment': -0.6846256128379277,
#   'neg_sentiment': 0.8571428571428571},
#  '2016-05-04': {'edit_count': 13,
#   'sentiment': -0.22604486116996178,
#   'neg_sentiment': 0.6153846153846154},
#  '2016-05-05': {'edit_count': 4,
#   'sentiment': -0.047127142548561096,
#   'neg_sentiment': 0.5},
#  '2016-05-06': {'edit_count': 1,
#   'sentiment': -0.9741126298904419,
#   'neg_sentiment': 1.0},
#  '2016-05-08': {'edit_count': 1,
#   'sentiment': 0.9415050745010376,
#   'neg_sentiment': 0.0},
#  '2016-05-10': {'edit_count': 2,
#   'sentiment': -0.06291237473487854,
#   'neg_sentiment': 0.5},
#  '2016-05-11': {'edit_count': 5,
#   'sentiment': -0.6251043677330017,
#   'neg_sentiment': 0.8},
#  '2016-05-12': {'edit_count': 7,
#   'sentiment': -0.8930428113256182,
#   'neg_sentiment': 1.0},
#  '2016-05-13': {'edit_count': 2,
#   'sentiment': -0.9984162449836731,
#   'neg_sentiment': 1.0},
#  '2016-05-14': {'edit_count': 14,
#   'sentiment': -0.7314948695046561,
#   'neg_sentiment': 0.9285714285714286},
#  '2016-05-15': {'edit_count': 9,
#   'sentiment': -0.546588679154714,
#   'neg_sentiment': 0.7777777777777778},
#  '2016-05-16': {'edit_count': 3,
#   'sentiment': -0.33912257353464764,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-05-20': {'edit_count': 6,
#   'sentiment': -0.37418797612190247,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-05-21': {'edit_count': 6,
#   'sentiment': -0.6488677859306335,
#   'neg_sentiment': 0.8333333333333334},
#  '2016-05-22': {'edit_count': 8,
#   'sentiment': -0.5242120176553726,
#   'neg_sentiment': 0.75},
#  '2016-05-23': {'edit_count': 1,
#   'sentiment': 0.9624135494232178,
#   'neg_sentiment': 0.0},
#  '2016-05-24': {'edit_count': 6,
#   'sentiment': -0.9979275365670522,
#   'neg_sentiment': 1.0},
#  '2016-05-25': {'edit_count': 12,
#   'sentiment': -0.29218168556690216,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-05-26': {'edit_count': 1,
#   'sentiment': -0.9993895292282104,
#   'neg_sentiment': 1.0},
#  '2016-05-27': {'edit_count': 4,
#   'sentiment': -0.9900326430797577,
#   'neg_sentiment': 1.0},
#  '2016-05-29': {'edit_count': 12,
#   'sentiment': -0.9400877853234609,
#   'neg_sentiment': 1.0},
#  '2016-05-31': {'edit_count': 1,
#   'sentiment': -0.9707022309303284,
#   'neg_sentiment': 1.0},
#  '2016-06-02': {'edit_count': 2,
#   'sentiment': -0.010445773601531982,
#   'neg_sentiment': 0.5},
#  '2016-06-03': {'edit_count': 8,
#   'sentiment': -0.7900542691349983,
#   'neg_sentiment': 0.875},
#  '2016-06-04': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2016-06-06': {'edit_count': 2,
#   'sentiment': -0.8267582654953003,
#   'neg_sentiment': 1.0},
#  '2016-06-07': {'edit_count': 2,
#   'sentiment': 0.7574344277381897,
#   'neg_sentiment': 0.0},
#  '2016-06-08': {'edit_count': 4,
#   'sentiment': -0.9992156773805618,
#   'neg_sentiment': 1.0},
#  '2016-06-09': {'edit_count': 4,
#   'sentiment': -0.4996437579393387,
#   'neg_sentiment': 0.75},
#  '2016-06-11': {'edit_count': 9,
#   'sentiment': -0.13607541057798597,
#   'neg_sentiment': 0.5555555555555556},
#  '2016-06-12': {'edit_count': 8,
#   'sentiment': -0.23851905763149261,
#   'neg_sentiment': 0.625},
#  '2016-06-13': {'edit_count': 8,
#   'sentiment': -0.7454900145530701,
#   'neg_sentiment': 0.875},
#  '2016-06-14': {'edit_count': 6,
#   'sentiment': -0.9876586000124613,
#   'neg_sentiment': 1.0},
#  '2016-06-15': {'edit_count': 2,
#   'sentiment': -0.9881815910339355,
#   'neg_sentiment': 1.0},
#  '2016-06-16': {'edit_count': 5,
#   'sentiment': 0.09599407911300659,
#   'neg_sentiment': 0.4},
#  '2016-06-17': {'edit_count': 29,
#   'sentiment': -0.1600025460637849,
#   'neg_sentiment': 0.5862068965517241},
#  '2016-06-18': {'edit_count': 4,
#   'sentiment': -0.032117024064064026,
#   'neg_sentiment': 0.5},
#  '2016-06-19': {'edit_count': 7,
#   'sentiment': -0.9941013285091945,
#   'neg_sentiment': 1.0},
#  '2016-06-20': {'edit_count': 4,
#   'sentiment': -0.35163238644599915,
#   'neg_sentiment': 0.75},
#  '2016-06-21': {'edit_count': 13,
#   'sentiment': -0.3419947028160095,
#   'neg_sentiment': 0.6923076923076923},
#  '2016-06-22': {'edit_count': 8,
#   'sentiment': -0.7496749013662338,
#   'neg_sentiment': 0.875},
#  '2016-06-23': {'edit_count': 7,
#   'sentiment': -0.3755743588720049,
#   'neg_sentiment': 0.7142857142857143},
#  '2016-06-24': {'edit_count': 1,
#   'sentiment': -0.9965983033180237,
#   'neg_sentiment': 1.0},
#  '2016-06-25': {'edit_count': 1,
#   'sentiment': 0.9563499093055725,
#   'neg_sentiment': 0.0},
#  '2016-06-27': {'edit_count': 2,
#   'sentiment': 0.0005915462970733643,
#   'neg_sentiment': 0.5},
#  '2016-06-28': {'edit_count': 2,
#   'sentiment': -0.1256324052810669,
#   'neg_sentiment': 0.5},
#  '2016-07-03': {'edit_count': 7,
#   'sentiment': -0.9934009313583374,
#   'neg_sentiment': 1.0},
#  '2016-07-04': {'edit_count': 15,
#   'sentiment': -0.2812794844309489,
#   'neg_sentiment': 0.6},
#  '2016-07-05': {'edit_count': 1,
#   'sentiment': -0.9994049072265625,
#   'neg_sentiment': 1.0},
#  '2016-07-10': {'edit_count': 3,
#   'sentiment': -0.3308367927869161,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-07-11': {'edit_count': 3,
#   'sentiment': -0.3378524382909139,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-07-13': {'edit_count': 1,
#   'sentiment': 0.9926652312278748,
#   'neg_sentiment': 0.0},
#  '2016-07-14': {'edit_count': 1,
#   'sentiment': -0.9997979998588562,
#   'neg_sentiment': 1.0},
#  '2016-07-18': {'edit_count': 6,
#   'sentiment': -0.9843528171380361,
#   'neg_sentiment': 1.0},
#  '2016-07-19': {'edit_count': 2,
#   'sentiment': -0.0020936429500579834,
#   'neg_sentiment': 0.5},
#  '2016-07-20': {'edit_count': 11,
#   'sentiment': -0.34380089152943005,
#   'neg_sentiment': 0.6363636363636364},
#  '2016-07-21': {'edit_count': 7,
#   'sentiment': -0.9954533236367362,
#   'neg_sentiment': 1.0},
#  '2016-07-24': {'edit_count': 1,
#   'sentiment': 0.9973074197769165,
#   'neg_sentiment': 0.0},
#  '2016-07-25': {'edit_count': 42,
#   'sentiment': -0.02596460921423776,
#   'neg_sentiment': 0.47619047619047616},
#  '2016-07-26': {'edit_count': 4,
#   'sentiment': -0.9009867012500763,
#   'neg_sentiment': 1.0},
#  '2016-07-29': {'edit_count': 1,
#   'sentiment': 0.9793362021446228,
#   'neg_sentiment': 0.0},
#  '2016-08-01': {'edit_count': 1,
#   'sentiment': -0.99940025806427,
#   'neg_sentiment': 1.0},
#  '2016-08-02': {'edit_count': 4,
#   'sentiment': -0.997414842247963,
#   'neg_sentiment': 1.0},
#  '2016-08-03': {'edit_count': 3,
#   'sentiment': 0.3303035497665405,
#   'neg_sentiment': 0.3333333333333333},
#  '2016-08-04': {'edit_count': 10,
#   'sentiment': -0.5950230598449707,
#   'neg_sentiment': 0.8},
#  '2016-08-05': {'edit_count': 2,
#   'sentiment': -0.9936567842960358,
#   'neg_sentiment': 1.0},
#  '2016-08-06': {'edit_count': 2,
#   'sentiment': -0.9767766296863556,
#   'neg_sentiment': 1.0},
#  '2016-08-10': {'edit_count': 1,
#   'sentiment': 0.9841746687889099,
#   'neg_sentiment': 0.0},
#  '2016-08-11': {'edit_count': 1,
#   'sentiment': -0.9998180270195007,
#   'neg_sentiment': 1.0},
#  '2016-08-12': {'edit_count': 2,
#   'sentiment': 0.07081541419029236,
#   'neg_sentiment': 0.5},
#  '2016-08-13': {'edit_count': 4,
#   'sentiment': -0.5157119482755661,
#   'neg_sentiment': 0.75},
#  '2016-08-16': {'edit_count': 3,
#   'sentiment': -0.3314799865086873,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-08-17': {'edit_count': 5,
#   'sentiment': -0.6872753739356995,
#   'neg_sentiment': 0.8},
#  '2016-08-18': {'edit_count': 1,
#   'sentiment': -0.9976456761360168,
#   'neg_sentiment': 1.0},
#  '2016-08-19': {'edit_count': 6,
#   'sentiment': -0.6231929461161295,
#   'neg_sentiment': 0.8333333333333334},
#  '2016-08-20': {'edit_count': 8,
#   'sentiment': -0.29933449625968933,
#   'neg_sentiment': 0.625},
#  '2016-08-21': {'edit_count': 2,
#   'sentiment': 0.8551968932151794,
#   'neg_sentiment': 0.0},
#  '2016-08-22': {'edit_count': 9,
#   'sentiment': -0.5528351730770535,
#   'neg_sentiment': 0.7777777777777778},
#  '2016-08-23': {'edit_count': 16,
#   'sentiment': -0.47111643850803375,
#   'neg_sentiment': 0.75},
#  '2016-08-24': {'edit_count': 1,
#   'sentiment': -0.9995619654655457,
#   'neg_sentiment': 1.0},
#  '2016-08-25': {'edit_count': 25,
#   'sentiment': -0.18705443382263184,
#   'neg_sentiment': 0.6},
#  '2016-08-26': {'edit_count': 7,
#   'sentiment': -0.7059491787637983,
#   'neg_sentiment': 0.8571428571428571},
#  '2016-08-27': {'edit_count': 8,
#   'sentiment': -0.24832218885421753,
#   'neg_sentiment': 0.625},
#  '2016-08-28': {'edit_count': 8,
#   'sentiment': -0.7478294223546982,
#   'neg_sentiment': 0.875},
#  '2016-08-29': {'edit_count': 9,
#   'sentiment': -0.7818647027015686,
#   'neg_sentiment': 0.8888888888888888},
#  '2016-08-30': {'edit_count': 15,
#   'sentiment': -0.5919451435407003,
#   'neg_sentiment': 0.8},
#  '2016-08-31': {'edit_count': 14,
#   'sentiment': -0.4436098337173462,
#   'neg_sentiment': 0.7142857142857143},
#  '2016-09-01': {'edit_count': 4,
#   'sentiment': -0.9962148517370224,
#   'neg_sentiment': 1.0},
#  '2016-09-02': {'edit_count': 7,
#   'sentiment': -0.4404781035014561,
#   'neg_sentiment': 0.7142857142857143},
#  '2016-09-03': {'edit_count': 4,
#   'sentiment': 0.04423844814300537,
#   'neg_sentiment': 0.5},
#  '2016-09-04': {'edit_count': 4,
#   'sentiment': -0.5206075310707092,
#   'neg_sentiment': 0.75},
#  '2016-09-06': {'edit_count': 13,
#   'sentiment': -0.9628888093508207,
#   'neg_sentiment': 1.0},
#  '2016-09-07': {'edit_count': 5,
#   'sentiment': -0.9732577919960022,
#   'neg_sentiment': 1.0},
#  '2016-09-10': {'edit_count': 1,
#   'sentiment': -0.99940025806427,
#   'neg_sentiment': 1.0},
#  '2016-09-13': {'edit_count': 7,
#   'sentiment': -0.9954042264393398,
#   'neg_sentiment': 1.0},
#  '2016-09-14': {'edit_count': 6,
#   'sentiment': -0.972339928150177,
#   'neg_sentiment': 1.0},
#  '2016-09-15': {'edit_count': 2,
#   'sentiment': -0.9992859959602356,
#   'neg_sentiment': 1.0},
#  '2016-09-16': {'edit_count': 3,
#   'sentiment': -0.3349811832110087,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-09-17': {'edit_count': 3,
#   'sentiment': -0.6909798383712769,
#   'neg_sentiment': 1.0},
#  '2016-09-19': {'edit_count': 2,
#   'sentiment': 0.9517807960510254,
#   'neg_sentiment': 0.0},
#  '2016-09-27': {'edit_count': 2,
#   'sentiment': -0.11880826950073242,
#   'neg_sentiment': 0.5},
#  '2016-10-05': {'edit_count': 2,
#   'sentiment': -0.9983959197998047,
#   'neg_sentiment': 1.0},
#  '2016-10-06': {'edit_count': 6,
#   'sentiment': 0.2094674507776896,
#   'neg_sentiment': 0.3333333333333333},
#  '2016-10-07': {'edit_count': 21,
#   'sentiment': -0.43851988656180246,
#   'neg_sentiment': 0.7619047619047619},
#  '2016-10-08': {'edit_count': 1,
#   'sentiment': -0.9991740584373474,
#   'neg_sentiment': 1.0},
#  '2016-10-09': {'edit_count': 1,
#   'sentiment': -0.9994413256645203,
#   'neg_sentiment': 1.0},
#  '2016-10-14': {'edit_count': 2,
#   'sentiment': -0.12506690621376038,
#   'neg_sentiment': 0.5},
#  '2016-10-15': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2016-10-18': {'edit_count': 2,
#   'sentiment': -0.9871054887771606,
#   'neg_sentiment': 1.0},
#  '2016-10-25': {'edit_count': 1,
#   'sentiment': 0.9993793964385986,
#   'neg_sentiment': 0.0},
#  '2016-10-27': {'edit_count': 1,
#   'sentiment': -0.9990171194076538,
#   'neg_sentiment': 1.0},
#  '2016-10-28': {'edit_count': 2,
#   'sentiment': -0.12444940209388733,
#   'neg_sentiment': 0.5},
#  '2016-11-04': {'edit_count': 2,
#   'sentiment': 0.7974672019481659,
#   'neg_sentiment': 0.0},
#  '2016-11-05': {'edit_count': 2,
#   'sentiment': -0.9830459356307983,
#   'neg_sentiment': 1.0},
#  '2016-11-07': {'edit_count': 3,
#   'sentiment': 0.33257120847702026,
#   'neg_sentiment': 0.3333333333333333},
#  '2016-11-08': {'edit_count': 3,
#   'sentiment': -0.9984327952067057,
#   'neg_sentiment': 1.0},
#  '2016-11-10': {'edit_count': 1,
#   'sentiment': -0.999127209186554,
#   'neg_sentiment': 1.0},
#  '2016-11-15': {'edit_count': 3,
#   'sentiment': -0.8960372010866801,
#   'neg_sentiment': 1.0},
#  '2016-11-16': {'edit_count': 1,
#   'sentiment': -0.9977920055389404,
#   'neg_sentiment': 1.0},
#  '2016-11-21': {'edit_count': 2,
#   'sentiment': -0.9396932423114777,
#   'neg_sentiment': 1.0},
#  '2016-11-22': {'edit_count': 4,
#   'sentiment': -0.8759122341871262,
#   'neg_sentiment': 1.0},
#  '2016-11-23': {'edit_count': 13,
#   'sentiment': -0.42797837349084705,
#   'neg_sentiment': 0.6923076923076923},
#  '2016-11-25': {'edit_count': 1,
#   'sentiment': 0.9624135494232178,
#   'neg_sentiment': 0.0},
#  '2016-11-26': {'edit_count': 1,
#   'sentiment': -0.9949942231178284,
#   'neg_sentiment': 1.0},
#  '2016-11-27': {'edit_count': 1,
#   'sentiment': -0.9941496849060059,
#   'neg_sentiment': 1.0},
#  '2016-11-28': {'edit_count': 1,
#   'sentiment': -0.9941496849060059,
#   'neg_sentiment': 1.0},
#  '2016-12-01': {'edit_count': 1,
#   'sentiment': -0.9984225034713745,
#   'neg_sentiment': 1.0},
#  '2016-12-02': {'edit_count': 2,
#   'sentiment': -0.1257205307483673,
#   'neg_sentiment': 0.5},
#  '2016-12-04': {'edit_count': 1,
#   'sentiment': -0.9634917378425598,
#   'neg_sentiment': 1.0},
#  '2016-12-07': {'edit_count': 3,
#   'sentiment': -0.41169053316116333,
#   'neg_sentiment': 0.6666666666666666},
#  '2016-12-12': {'edit_count': 12,
#   'sentiment': -0.9273687601089478,
#   'neg_sentiment': 1.0},
#  '2016-12-14': {'edit_count': 8,
#   'sentiment': -0.2552844360470772,
#   'neg_sentiment': 0.625},
#  '2016-12-15': {'edit_count': 4,
#   'sentiment': 0.47455573081970215,
#   'neg_sentiment': 0.25},
#  '2016-12-16': {'edit_count': 1,
#   'sentiment': -0.9883756637573242,
#   'neg_sentiment': 1.0},
#  '2016-12-17': {'edit_count': 3,
#   'sentiment': -0.9603152871131897,
#   'neg_sentiment': 1.0},
#  '2016-12-22': {'edit_count': 1,
#   'sentiment': 0.9861398935317993,
#   'neg_sentiment': 0.0},
#  '2016-12-23': {'edit_count': 1,
#   'sentiment': -0.969271183013916,
#   'neg_sentiment': 1.0},
#  '2016-12-28': {'edit_count': 1,
#   'sentiment': -0.9803714156150818,
#   'neg_sentiment': 1.0},
#  '2016-12-30': {'edit_count': 1,
#   'sentiment': -0.9954804182052612,
#   'neg_sentiment': 1.0},
#  '2017-01-03': {'edit_count': 5,
#   'sentiment': 0.006335902214050293,
#   'neg_sentiment': 0.4},
#  '2017-01-04': {'edit_count': 1,
#   'sentiment': -0.9986360669136047,
#   'neg_sentiment': 1.0},
#  '2017-01-08': {'edit_count': 2,
#   'sentiment': -0.9033949971199036,
#   'neg_sentiment': 1.0},
#  '2017-01-11': {'edit_count': 1,
#   'sentiment': -0.9951227307319641,
#   'neg_sentiment': 1.0},
#  '2017-01-15': {'edit_count': 22,
#   'sentiment': 0.2882602404464375,
#   'neg_sentiment': 0.3181818181818182},
#  '2017-01-17': {'edit_count': 2,
#   'sentiment': 0.08332976698875427,
#   'neg_sentiment': 0.5},
#  '2017-01-18': {'edit_count': 2,
#   'sentiment': -0.18368187546730042,
#   'neg_sentiment': 0.5},
#  '2017-01-19': {'edit_count': 1,
#   'sentiment': -0.9984684586524963,
#   'neg_sentiment': 1.0},
#  '2017-01-21': {'edit_count': 3,
#   'sentiment': -0.41644235452016193,
#   'neg_sentiment': 0.6666666666666666},
#  '2017-01-24': {'edit_count': 1,
#   'sentiment': -0.9076561331748962,
#   'neg_sentiment': 1.0},
#  '2017-01-30': {'edit_count': 2,
#   'sentiment': -0.125742107629776,
#   'neg_sentiment': 0.5},
#  '2017-02-03': {'edit_count': 1,
#   'sentiment': -0.9960384368896484,
#   'neg_sentiment': 1.0},
#  '2017-02-06': {'edit_count': 3,
#   'sentiment': -0.7188589175542196,
#   'neg_sentiment': 1.0},
#  '2017-02-08': {'edit_count': 7,
#   'sentiment': -0.9972683531897408,
#   'neg_sentiment': 1.0},
#  '2017-02-10': {'edit_count': 7,
#   'sentiment': 0.6909534335136414,
#   'neg_sentiment': 0.14285714285714285},
#  '2017-02-12': {'edit_count': 1,
#   'sentiment': -0.9992103576660156,
#   'neg_sentiment': 1.0},
#  '2017-02-16': {'edit_count': 3,
#   'sentiment': 0.8306657473246256,
#   'neg_sentiment': 0.0},
#  '2017-02-24': {'edit_count': 9,
#   'sentiment': -0.93689583407508,
#   'neg_sentiment': 1.0},
#  '2017-02-26': {'edit_count': 1,
#   'sentiment': 0.977993905544281,
#   'neg_sentiment': 0.0},
#  '2017-02-27': {'edit_count': 2,
#   'sentiment': -0.005706876516342163,
#   'neg_sentiment': 0.5},
#  '2017-02-28': {'edit_count': 2,
#   'sentiment': -0.0020550787448883057,
#   'neg_sentiment': 0.5},
#  '2017-03-01': {'edit_count': 2,
#   'sentiment': -0.9752084910869598,
#   'neg_sentiment': 1.0},
#  '2017-03-02': {'edit_count': 1,
#   'sentiment': -0.999404788017273,
#   'neg_sentiment': 1.0},
#  '2017-03-03': {'edit_count': 2,
#   'sentiment': -0.9926957488059998,
#   'neg_sentiment': 1.0},
#  '2017-03-06': {'edit_count': 1,
#   'sentiment': -0.9982559084892273,
#   'neg_sentiment': 1.0},
#  '2017-03-11': {'edit_count': 1,
#   'sentiment': -0.9965848922729492,
#   'neg_sentiment': 1.0},
#  '2017-03-13': {'edit_count': 4,
#   'sentiment': 0.8667450249195099,
#   'neg_sentiment': 0.0},
#  '2017-03-15': {'edit_count': 3,
#   'sentiment': -0.2938867410024007,
#   'neg_sentiment': 0.6666666666666666},
#  '2017-03-16': {'edit_count': 2,
#   'sentiment': -0.08098992705345154,
#   'neg_sentiment': 0.5},
#  '2017-03-17': {'edit_count': 2,
#   'sentiment': 0.8736345767974854,
#   'neg_sentiment': 0.0},
#  '2017-03-19': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2017-03-21': {'edit_count': 2,
#   'sentiment': 0.9762290120124817,
#   'neg_sentiment': 0.0},
#  '2017-03-22': {'edit_count': 1,
#   'sentiment': -0.9987133741378784,
#   'neg_sentiment': 1.0},
#  '2017-03-24': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2017-03-25': {'edit_count': 2,
#   'sentiment': -0.7570517063140869,
#   'neg_sentiment': 1.0},
#  '2017-03-26': {'edit_count': 1,
#   'sentiment': -0.9994961023330688,
#   'neg_sentiment': 1.0},
#  '2017-04-02': {'edit_count': 3,
#   'sentiment': 0.3165348569552104,
#   'neg_sentiment': 0.3333333333333333},
#  '2017-04-15': {'edit_count': 1,
#   'sentiment': -0.9033949971199036,
#   'neg_sentiment': 1.0},
#  '2017-04-16': {'edit_count': 3,
#   'sentiment': -0.36034059524536133,
#   'neg_sentiment': 0.6666666666666666},
#  '2017-04-18': {'edit_count': 2,
#   'sentiment': -0.8089325726032257,
#   'neg_sentiment': 1.0},
#  '2017-04-20': {'edit_count': 6,
#   'sentiment': 0.20421022176742554,
#   'neg_sentiment': 0.3333333333333333},
#  '2017-04-21': {'edit_count': 1,
#   'sentiment': 0.8947147130966187,
#   'neg_sentiment': 0.0},
#  '2017-04-22': {'edit_count': 1,
#   'sentiment': -0.9771077632904053,
#   'neg_sentiment': 1.0},
#  '2017-04-24': {'edit_count': 1,
#   'sentiment': -0.9690083265304565,
#   'neg_sentiment': 1.0},
#  '2017-04-26': {'edit_count': 8,
#   'sentiment': 0.09169413894414902,
#   'neg_sentiment': 0.375},
#  '2017-04-27': {'edit_count': 5,
#   'sentiment': -0.6086325764656066,
#   'neg_sentiment': 0.8},
#  '2017-04-29': {'edit_count': 2,
#   'sentiment': -0.9560004770755768,
#   'neg_sentiment': 1.0},
#  '2017-04-30': {'edit_count': 1,
#   'sentiment': -0.9793100357055664,
#   'neg_sentiment': 1.0},
#  '2017-05-02': {'edit_count': 2,
#   'sentiment': -0.988718181848526,
#   'neg_sentiment': 1.0},
#  '2017-05-03': {'edit_count': 3,
#   'sentiment': 0.8281575441360474,
#   'neg_sentiment': 0.0},
#  '2017-05-04': {'edit_count': 2,
#   'sentiment': 0.98823082447052,
#   'neg_sentiment': 0.0},
#  '2017-05-05': {'edit_count': 7,
#   'sentiment': -0.9415187835693359,
#   'neg_sentiment': 1.0},
#  '2017-05-06': {'edit_count': 9,
#   'sentiment': -0.5330058799849616,
#   'neg_sentiment': 0.7777777777777778},
#  '2017-05-07': {'edit_count': 7,
#   'sentiment': 0.06752476521900722,
#   'neg_sentiment': 0.42857142857142855},
#  '2017-05-08': {'edit_count': 7,
#   'sentiment': -0.8776093806539264,
#   'neg_sentiment': 1.0},
#  '2017-05-09': {'edit_count': 5,
#   'sentiment': -0.28191418647766114,
#   'neg_sentiment': 0.6},
#  '2017-05-10': {'edit_count': 3,
#   'sentiment': -0.3981425960858663,
#   'neg_sentiment': 0.6666666666666666},
#  '2017-05-11': {'edit_count': 2,
#   'sentiment': -0.9306546151638031,
#   'neg_sentiment': 1.0},
#  '2017-05-14': {'edit_count': 2,
#   'sentiment': -0.04890123009681702,
#   'neg_sentiment': 0.5},
#  '2017-05-15': {'edit_count': 9,
#   'sentiment': -0.1583675874604119,
#   'neg_sentiment': 0.5555555555555556},
#  '2017-05-16': {'edit_count': 8,
#   'sentiment': -0.7443529367446899,
#   'neg_sentiment': 0.875},
#  '2017-05-17': {'edit_count': 4,
#   'sentiment': -0.8102264106273651,
#   'neg_sentiment': 1.0},
#  '2017-05-18': {'edit_count': 5,
#   'sentiment': -0.6387836098670959,
#   'neg_sentiment': 0.8},
#  '2017-05-20': {'edit_count': 1,
#   'sentiment': -0.9953629970550537,
#   'neg_sentiment': 1.0},
#  '2017-05-25': {'edit_count': 3,
#   'sentiment': -0.41284475723902386,
#   'neg_sentiment': 0.6666666666666666},
#  '2017-05-26': {'edit_count': 3,
#   'sentiment': -0.986102839310964,
#   'neg_sentiment': 1.0},
#  '2017-05-27': {'edit_count': 8,
#   'sentiment': -0.7507810816168785,
#   'neg_sentiment': 0.875},
#  '2017-05-28': {'edit_count': 1,
#   'sentiment': -0.9965848922729492,
#   'neg_sentiment': 1.0},
#  '2017-05-29': {'edit_count': 1,
#   'sentiment': -0.9892553091049194,
#   'neg_sentiment': 1.0},
#  '2017-05-30': {'edit_count': 3,
#   'sentiment': 0.2476862668991089,
#   'neg_sentiment': 0.3333333333333333},
#  '2017-05-31': {'edit_count': 2,
#   'sentiment': -0.1246991753578186,
#   'neg_sentiment': 0.5},
#  '2017-06-01': {'edit_count': 1,
#   'sentiment': -0.998914361000061,
#   'neg_sentiment': 1.0},
#  '2017-06-03': {'edit_count': 8,
#   'sentiment': -0.297838494181633,
#   'neg_sentiment': 0.625},
#  '2017-06-04': {'edit_count': 4,
#   'sentiment': -0.9965332746505737,
#   'neg_sentiment': 1.0},
#  '2017-06-05': {'edit_count': 1,
#   'sentiment': 0.7112514972686768,
#   'neg_sentiment': 0.0},
#  '2017-06-06': {'edit_count': 4,
#   'sentiment': -0.9971695989370346,
#   'neg_sentiment': 1.0},
#  '2017-06-07': {'edit_count': 6,
#   'sentiment': -0.37490230798721313,
#   'neg_sentiment': 0.6666666666666666},
#  '2017-06-12': {'edit_count': 4,
#   'sentiment': -0.4908546954393387,
#   'neg_sentiment': 0.75},
#  '2017-06-13': {'edit_count': 1,
#   'sentiment': 0.9854654669761658,
#   'neg_sentiment': 0.0},
#  '2017-06-14': {'edit_count': 1,
#   'sentiment': -0.9936001300811768,
#   'neg_sentiment': 1.0},
#  '2017-06-15': {'edit_count': 4,
#   'sentiment': -0.07259652018547058,
#   'neg_sentiment': 0.5},
#  '2017-06-16': {'edit_count': 1,
#   'sentiment': 0.7779265642166138,
#   'neg_sentiment': 0.0},
#  '2017-06-17': {'edit_count': 4,
#   'sentiment': -0.03456112742424011,
#   'neg_sentiment': 0.5},
#  '2017-06-18': {'edit_count': 3,
#   'sentiment': -0.998042623202006,
#   'neg_sentiment': 1.0},
#  '2017-06-19': {'edit_count': 5,
#   'sentiment': -0.998740816116333,
#   'neg_sentiment': 1.0},
#  '2017-06-20': {'edit_count': 9,
#   'sentiment': -0.7971505853864882,
#   'neg_sentiment': 0.8888888888888888},
#  '2017-06-21': {'edit_count': 1,
#   'sentiment': -0.9993568062782288,
#   'neg_sentiment': 1.0},
#  '2017-06-22': {'edit_count': 4,
#   'sentiment': -0.5036364495754242,
#   'neg_sentiment': 0.75},
#  '2017-06-23': {'edit_count': 5,
#   'sentiment': 0.39879409074783323,
#   'neg_sentiment': 0.2},
#  '2017-06-24': {'edit_count': 3,
#   'sentiment': -0.33382221062978107,
#   'neg_sentiment': 0.6666666666666666},
#  '2017-06-25': {'edit_count': 1,
#   'sentiment': 0.9926058053970337,
#   'neg_sentiment': 0.0},
#  '2017-06-26': {'edit_count': 3,
#   'sentiment': -0.2175831993420919,
#   'neg_sentiment': 0.6666666666666666},
#  '2017-06-29': {'edit_count': 1,
#   'sentiment': -0.9984440207481384,
#   'neg_sentiment': 1.0},
#  '2017-06-30': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2017-07-02': {'edit_count': 1,
#   'sentiment': -0.9994275569915771,
#   'neg_sentiment': 1.0},
#  '2017-07-03': {'edit_count': 1,
#   'sentiment': 0.572674036026001,
#   'neg_sentiment': 0.0},
#  '2017-07-04': {'edit_count': 5,
#   'sentiment': -0.9905186057090759,
#   'neg_sentiment': 1.0},
#  '2017-07-07': {'edit_count': 1,
#   'sentiment': -0.9983868598937988,
#   'neg_sentiment': 1.0},
#  '2017-07-08': {'edit_count': 6,
#   'sentiment': -0.03486520051956177,
#   'neg_sentiment': 0.5},
#  '2017-07-09': {'edit_count': 3,
#   'sentiment': -0.9919910828272501,
#   'neg_sentiment': 1.0},
#  '2017-07-10': {'edit_count': 1,
#   'sentiment': -0.6338395476341248,
#   'neg_sentiment': 1.0},
#  '2017-07-11': {'edit_count': 3,
#   'sentiment': -0.9995575944582621,
#   'neg_sentiment': 1.0},
#  '2017-07-12': {'edit_count': 3,
#   'sentiment': -0.450897216796875,
#   'neg_sentiment': 0.6666666666666666},
#  '2017-07-13': {'edit_count': 2,
#   'sentiment': -0.9986920058727264,
#   'neg_sentiment': 1.0},
#  '2017-07-15': {'edit_count': 4,
#   'sentiment': -0.9773373752832413,
#   'neg_sentiment': 1.0},
#  '2017-07-18': {'edit_count': 9,
#   'sentiment': -0.7668788366847568,
#   'neg_sentiment': 0.8888888888888888},
#  '2017-07-19': {'edit_count': 3,
#   'sentiment': -0.4161985119183858,
#   'neg_sentiment': 0.6666666666666666},
#  '2017-07-21': {'edit_count': 1,
#   'sentiment': -0.9956009387969971,
#   'neg_sentiment': 1.0},
#  '2017-07-26': {'edit_count': 1,
#   'sentiment': -0.9970057606697083,
#   'neg_sentiment': 1.0},
#  '2017-07-27': {'edit_count': 1,
#   'sentiment': -0.9995869994163513,
#   'neg_sentiment': 1.0},
#  '2017-07-29': {'edit_count': 3,
#   'sentiment': -0.9962882002194723,
#   'neg_sentiment': 1.0},
#  '2017-07-30': {'edit_count': 7,
#   'sentiment': -0.9985508663313729,
#   'neg_sentiment': 1.0},
#  '2017-07-31': {'edit_count': 1,
#   'sentiment': 0.8736134767532349,
#   'neg_sentiment': 0.0},
#  '2017-08-03': {'edit_count': 3,
#   'sentiment': -0.9968375960985819,
#   'neg_sentiment': 1.0},
#  '2017-08-04': {'edit_count': 2,
#   'sentiment': 0.06844568252563477,
#   'neg_sentiment': 0.5},
#  '2017-08-06': {'edit_count': 3,
#   'sentiment': -0.9996159275372823,
#   'neg_sentiment': 1.0},
#  '2017-08-07': {'edit_count': 2,
#   'sentiment': -0.12379473447799683,
#   'neg_sentiment': 0.5},
#  '2017-08-08': {'edit_count': 5,
#   'sentiment': -0.2027851939201355,
#   'neg_sentiment': 0.6},
#  '2017-08-09': {'edit_count': 8,
#   'sentiment': -0.5203342363238335,
#   'neg_sentiment': 0.75},
#  '2017-08-10': {'edit_count': 1,
#   'sentiment': -0.9996277093887329,
#   'neg_sentiment': 1.0},
#  '2017-08-13': {'edit_count': 2,
#   'sentiment': -0.9538321793079376,
#   'neg_sentiment': 1.0},
#  '2017-08-15': {'edit_count': 4,
#   'sentiment': -0.8894386738538742,
#   'neg_sentiment': 1.0},
#  '2017-08-17': {'edit_count': 5,
#   'sentiment': -0.6049571394920349,
#   'neg_sentiment': 0.8},
#  '2017-08-18': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2017-08-20': {'edit_count': 3,
#   'sentiment': 0.3303806980450948,
#   'neg_sentiment': 0.3333333333333333},
#  '2017-08-24': {'edit_count': 4,
#   'sentiment': -0.021031469106674194,
#   'neg_sentiment': 0.5},
#  '2017-08-27': {'edit_count': 6,
#   'sentiment': -0.7075432936350504,
#   'neg_sentiment': 0.8333333333333334},
#  '2017-08-28': {'edit_count': 1,
#   'sentiment': -0.9989960789680481,
#   'neg_sentiment': 1.0},
#  '2017-08-31': {'edit_count': 1,
#   'sentiment': -0.9589123129844666,
#   'neg_sentiment': 1.0},
#  '2017-09-01': {'edit_count': 3,
#   'sentiment': -0.9880576133728027,
#   'neg_sentiment': 1.0},
#  '2017-09-02': {'edit_count': 3,
#   'sentiment': -0.9789530237515768,
#   'neg_sentiment': 1.0},
#  '2017-09-04': {'edit_count': 1,
#   'sentiment': -0.9867420792579651,
#   'neg_sentiment': 1.0},
#  '2017-09-05': {'edit_count': 2,
#   'sentiment': -0.1214992105960846,
#   'neg_sentiment': 0.5},
#  '2017-09-06': {'edit_count': 1,
#   'sentiment': -0.9545263051986694,
#   'neg_sentiment': 1.0},
#  '2017-09-07': {'edit_count': 4,
#   'sentiment': -0.11842265725135803,
#   'neg_sentiment': 0.5},
#  '2017-09-09': {'edit_count': 1,
#   'sentiment': -0.9981949925422668,
#   'neg_sentiment': 1.0},
#  '2017-09-10': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2017-09-11': {'edit_count': 2,
#   'sentiment': -0.9901243448257446,
#   'neg_sentiment': 1.0},
#  '2017-09-14': {'edit_count': 2,
#   'sentiment': -0.12489050626754761,
#   'neg_sentiment': 0.5},
#  '2017-09-15': {'edit_count': 3,
#   'sentiment': -0.3457631667455037,
#   'neg_sentiment': 0.6666666666666666},
#  '2017-09-17': {'edit_count': 1,
#   'sentiment': 0.9970003962516785,
#   'neg_sentiment': 0.0},
#  '2017-09-20': {'edit_count': 2,
#   'sentiment': -0.9968039691448212,
#   'neg_sentiment': 1.0},
#  '2017-09-21': {'edit_count': 3,
#   'sentiment': 0.1762378215789795,
#   'neg_sentiment': 0.3333333333333333},
#  '2017-09-22': {'edit_count': 2,
#   'sentiment': -0.034496158361434937,
#   'neg_sentiment': 0.5},
#  '2017-09-24': {'edit_count': 8,
#   'sentiment': -0.4924352765083313,
#   'neg_sentiment': 0.75},
#  '2017-09-26': {'edit_count': 3,
#   'sentiment': 0.3315344254175822,
#   'neg_sentiment': 0.3333333333333333},
#  '2017-09-28': {'edit_count': 9,
#   'sentiment': -0.3149797320365906,
#   'neg_sentiment': 0.6666666666666666},
#  '2017-09-30': {'edit_count': 2,
#   'sentiment': -0.12111109495162964,
#   'neg_sentiment': 0.5},
#  '2017-10-01': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2017-10-02': {'edit_count': 1,
#   'sentiment': -0.9977224469184875,
#   'neg_sentiment': 1.0},
#  '2017-10-15': {'edit_count': 1,
#   'sentiment': -0.9814701676368713,
#   'neg_sentiment': 1.0},
#  '2017-10-16': {'edit_count': 3,
#   'sentiment': 0.24533482392628989,
#   'neg_sentiment': 0.3333333333333333},
#  '2017-10-18': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2017-10-22': {'edit_count': 2,
#   'sentiment': -0.8161042332649231,
#   'neg_sentiment': 1.0},
#  '2017-10-23': {'edit_count': 2,
#   'sentiment': -0.8163710534572601,
#   'neg_sentiment': 1.0},
#  '2017-10-24': {'edit_count': 2,
#   'sentiment': -0.9353103339672089,
#   'neg_sentiment': 1.0},
#  '2017-10-31': {'edit_count': 4,
#   'sentiment': -0.5554662197828293,
#   'neg_sentiment': 0.75},
#  '2017-11-03': {'edit_count': 4,
#   'sentiment': 0.8016940653324127,
#   'neg_sentiment': 0.0},
#  '2017-11-07': {'edit_count': 4,
#   'sentiment': -0.5027263909578323,
#   'neg_sentiment': 0.75},
#  '2017-11-08': {'edit_count': 3,
#   'sentiment': -0.9863243897755941,
#   'neg_sentiment': 1.0},
#  '2017-11-09': {'edit_count': 1,
#   'sentiment': -0.5250791907310486,
#   'neg_sentiment': 1.0},
#  '2017-11-10': {'edit_count': 2,
#   'sentiment': -0.9991655945777893,
#   'neg_sentiment': 1.0},
#  '2017-11-13': {'edit_count': 4,
#   'sentiment': -0.9549326598644257,
#   'neg_sentiment': 1.0},
#  '2017-11-14': {'edit_count': 2,
#   'sentiment': -0.9972935020923615,
#   'neg_sentiment': 1.0},
#  '2017-11-17': {'edit_count': 4,
#   'sentiment': -0.8832715302705765,
#   'neg_sentiment': 1.0},
#  '2017-11-18': {'edit_count': 2,
#   'sentiment': -0.8158819377422333,
#   'neg_sentiment': 1.0},
#  '2017-11-19': {'edit_count': 3,
#   'sentiment': 0.33036645253499347,
#   'neg_sentiment': 0.3333333333333333},
#  '2017-11-20': {'edit_count': 2,
#   'sentiment': -0.03768381476402283,
#   'neg_sentiment': 0.5},
#  '2017-11-21': {'edit_count': 3,
#   'sentiment': -0.9704769055048624,
#   'neg_sentiment': 1.0},
#  '2017-11-23': {'edit_count': 1,
#   'sentiment': 0.9838104248046875,
#   'neg_sentiment': 0.0},
#  '2017-11-29': {'edit_count': 2,
#   'sentiment': -0.7784885466098785,
#   'neg_sentiment': 1.0},
#  '2017-11-30': {'edit_count': 1,
#   'sentiment': -0.9991235136985779,
#   'neg_sentiment': 1.0},
#  '2017-12-01': {'edit_count': 3,
#   'sentiment': -0.9893257816632589,
#   'neg_sentiment': 1.0},
#  '2017-12-03': {'edit_count': 4,
#   'sentiment': -0.0024823248386383057,
#   'neg_sentiment': 0.5},
#  '2017-12-04': {'edit_count': 1,
#   'sentiment': -0.9984032511711121,
#   'neg_sentiment': 1.0},
# ...
#  '2020-12-03': {'edit_count': 3,
#   'sentiment': -0.2877538204193115,
#   'neg_sentiment': 0.6666666666666666},
#  '2020-12-04': {'edit_count': 7,
#   'sentiment': -0.15785414831978933,
#   'neg_sentiment': 0.5714285714285714},
#  '2020-12-06': {'edit_count': 2,
#   'sentiment': 0.9742110073566437,
#   'neg_sentiment': 0.0},
#  '2020-12-07': {'edit_count': 2,
#   'sentiment': -0.014885514974594116,
#   'neg_sentiment': 0.5},
#  '2020-12-08': {'edit_count': 2,
#   'sentiment': -0.9989223480224609,
#   'neg_sentiment': 1.0},
#  '2020-12-09': {'edit_count': 1,
#   'sentiment': -0.9995208978652954,
#   'neg_sentiment': 1.0},
#  '2020-12-11': {'edit_count': 1,
#   'sentiment': -0.8901432156562805,
#   'neg_sentiment': 1.0},
#  '2020-12-13': {'edit_count': 3,
#   'sentiment': 0.977769156297048,
#   'neg_sentiment': 0.0},
#  '2020-12-14': {'edit_count': 10,
#   'sentiment': -0.04099710583686829,
#   'neg_sentiment': 0.5},
#  '2020-12-15': {'edit_count': 2,
#   'sentiment': -0.006532788276672363,
#   'neg_sentiment': 0.5},
#  '2020-12-16': {'edit_count': 4,
#   'sentiment': 0.3006356805562973,
#   'neg_sentiment': 0.25},
#  '2020-12-20': {'edit_count': 4,
#   'sentiment': -0.5620215535163879,
#   'neg_sentiment': 0.75},
#  '2020-12-21': {'edit_count': 7,
#   'sentiment': -0.06514915398189,
#   'neg_sentiment': 0.5714285714285714},
#  '2020-12-22': {'edit_count': 1,
#   'sentiment': 0.9624135494232178,
#   'neg_sentiment': 0.0},
#  '2020-12-23': {'edit_count': 3,
#   'sentiment': 0.9290298422177633,
#   'neg_sentiment': 0.0},
#  '2020-12-24': {'edit_count': 1,
#   'sentiment': -0.9994516968727112,
#   'neg_sentiment': 1.0},
#  '2020-12-26': {'edit_count': 1,
#   'sentiment': 0.9936618804931641,
#   'neg_sentiment': 0.0},
#  '2020-12-29': {'edit_count': 10,
#   'sentiment': -0.24139599204063417,
#   'neg_sentiment': 0.6},
#  '2020-12-30': {'edit_count': 2,
#   'sentiment': -0.9944261908531189,
#   'neg_sentiment': 1.0},
#  '2021-01-01': {'edit_count': 3,
#   'sentiment': -0.4144793152809143,
#   'neg_sentiment': 0.6666666666666666},
#  '2021-01-03': {'edit_count': 5,
#   'sentiment': -0.4828911185264587,
#   'neg_sentiment': 0.8},
#  '2021-01-04': {'edit_count': 7,
#   'sentiment': -0.14626310552869523,
#   'neg_sentiment': 0.5714285714285714},
#  '2021-01-05': {'edit_count': 5,
#   'sentiment': 0.1285001039505005,
#   'neg_sentiment': 0.4},
#  '2021-01-06': {'edit_count': 1,
#   'sentiment': -0.9996042847633362,
#   'neg_sentiment': 1.0},
#  '2021-01-12': {'edit_count': 2,
#   'sentiment': 0.0019700825214385986,
#   'neg_sentiment': 0.5},
#  '2021-01-16': {'edit_count': 9,
#   'sentiment': -0.16801293028725517,
#   'neg_sentiment': 0.5555555555555556},
#  '2021-01-18': {'edit_count': 4,
#   'sentiment': -0.125410795211792,
#   'neg_sentiment': 0.5},
#  '2021-01-19': {'edit_count': 3,
#   'sentiment': 0.26696791251500446,
#   'neg_sentiment': 0.3333333333333333},
#  '2021-01-20': {'edit_count': 7,
#   'sentiment': -0.4928120459829058,
#   'neg_sentiment': 0.7142857142857143},
#  '2021-01-21': {'edit_count': 7,
#   'sentiment': -0.7102866513388497,
#   'neg_sentiment': 0.8571428571428571},
#  '2021-01-22': {'edit_count': 6,
#   'sentiment': -0.3546476562817891,
#   'neg_sentiment': 0.6666666666666666},
#  '2021-01-24': {'edit_count': 1,
#   'sentiment': -0.9981043338775635,
#   'neg_sentiment': 1.0},
#  '2021-01-30': {'edit_count': 1,
#   'sentiment': -0.9970109462738037,
#   'neg_sentiment': 1.0},
#  '2021-02-05': {'edit_count': 1,
#   'sentiment': -0.9981270432472229,
#   'neg_sentiment': 1.0},
#  '2021-02-08': {'edit_count': 1,
#   'sentiment': -0.9835846424102783,
#   'neg_sentiment': 1.0},
#  '2021-02-12': {'edit_count': 2,
#   'sentiment': -0.0008479058742523193,
#   'neg_sentiment': 0.5},
#  '2021-02-13': {'edit_count': 1,
#   'sentiment': -0.9993706345558167,
#   'neg_sentiment': 1.0},
#  '2021-02-17': {'edit_count': 3,
#   'sentiment': -0.3774578372637431,
#   'neg_sentiment': 0.6666666666666666},
#  '2021-02-25': {'edit_count': 1,
#   'sentiment': -0.5030127167701721,
#   'neg_sentiment': 1.0},
#  '2021-02-27': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-03-03': {'edit_count': 1,
#   'sentiment': 0.9953556060791016,
#   'neg_sentiment': 0.0},
#  '2021-03-04': {'edit_count': 1,
#   'sentiment': -0.9996358156204224,
#   'neg_sentiment': 1.0},
#  '2021-03-07': {'edit_count': 2,
#   'sentiment': -0.0074935853481292725,
#   'neg_sentiment': 0.5},
#  '2021-03-10': {'edit_count': 1,
#   'sentiment': -0.9992116689682007,
#   'neg_sentiment': 1.0},
#  '2021-03-12': {'edit_count': 1,
#   'sentiment': -0.9991999268531799,
#   'neg_sentiment': 1.0},
#  '2021-03-16': {'edit_count': 4,
#   'sentiment': -0.052634477615356445,
#   'neg_sentiment': 0.5},
#  '2021-03-18': {'edit_count': 3,
#   'sentiment': -0.8470005591710409,
#   'neg_sentiment': 1.0},
#  '2021-03-19': {'edit_count': 2,
#   'sentiment': -0.998130202293396,
#   'neg_sentiment': 1.0},
#  '2021-03-22': {'edit_count': 1,
#   'sentiment': 0.9854480624198914,
#   'neg_sentiment': 0.0},
#  '2021-03-23': {'edit_count': 2,
#   'sentiment': -0.12541082501411438,
#   'neg_sentiment': 0.5},
#  '2021-03-25': {'edit_count': 1,
#   'sentiment': -0.9899972677230835,
#   'neg_sentiment': 1.0},
#  '2021-03-26': {'edit_count': 2,
#   'sentiment': -0.998397171497345,
#   'neg_sentiment': 1.0},
#  '2021-03-27': {'edit_count': 1,
#   'sentiment': 0.8787844181060791,
#   'neg_sentiment': 0.0},
#  '2021-03-28': {'edit_count': 2,
#   'sentiment': -0.9211370944976807,
#   'neg_sentiment': 1.0},
#  '2021-03-29': {'edit_count': 1,
#   'sentiment': -0.9803565144538879,
#   'neg_sentiment': 1.0},
#  '2021-03-31': {'edit_count': 5,
#   'sentiment': -0.6013561725616455,
#   'neg_sentiment': 0.8},
#  '2021-04-03': {'edit_count': 2,
#   'sentiment': -0.9361786544322968,
#   'neg_sentiment': 1.0},
#  '2021-04-04': {'edit_count': 4,
#   'sentiment': -0.8955419063568115,
#   'neg_sentiment': 1.0},
#  '2021-04-05': {'edit_count': 9,
#   'sentiment': -0.5025948087374369,
#   'neg_sentiment': 0.7777777777777778},
#  '2021-04-06': {'edit_count': 1,
#   'sentiment': -0.9915871620178223,
#   'neg_sentiment': 1.0},
#  '2021-04-08': {'edit_count': 4,
#   'sentiment': -0.09302225708961487,
#   'neg_sentiment': 0.5},
#  '2021-04-10': {'edit_count': 1,
#   'sentiment': 0.9895176291465759,
#   'neg_sentiment': 0.0},
#  '2021-04-11': {'edit_count': 2,
#   'sentiment': -0.9900562763214111,
#   'neg_sentiment': 1.0},
#  '2021-04-16': {'edit_count': 1,
#   'sentiment': 0.9550857543945312,
#   'neg_sentiment': 0.0},
#  '2021-04-17': {'edit_count': 1,
#   'sentiment': -0.7722337245941162,
#   'neg_sentiment': 1.0},
#  '2021-04-18': {'edit_count': 7,
#   'sentiment': 0.419821492263249,
#   'neg_sentiment': 0.2857142857142857},
#  '2021-04-19': {'edit_count': 8,
#   'sentiment': -0.2932688742876053,
#   'neg_sentiment': 0.625},
#  '2021-04-20': {'edit_count': 2,
#   'sentiment': -0.9928781390190125,
#   'neg_sentiment': 1.0},
#  '2021-04-21': {'edit_count': 2,
#   'sentiment': -0.9970972537994385,
#   'neg_sentiment': 1.0},
#  '2021-04-22': {'edit_count': 2,
#   'sentiment': -0.9969149827957153,
#   'neg_sentiment': 1.0},
#  '2021-04-23': {'edit_count': 2,
#   'sentiment': -0.9960430264472961,
#   'neg_sentiment': 1.0},
#  '2021-04-25': {'edit_count': 1,
#   'sentiment': -0.9953306913375854,
#   'neg_sentiment': 1.0},
#  '2021-04-27': {'edit_count': 1,
#   'sentiment': 0.6582769751548767,
#   'neg_sentiment': 0.0},
#  '2021-05-04': {'edit_count': 3,
#   'sentiment': -0.39125923315684,
#   'neg_sentiment': 0.6666666666666666},
#  '2021-05-05': {'edit_count': 1,
#   'sentiment': -0.9898121953010559,
#   'neg_sentiment': 1.0},
#  '2021-05-06': {'edit_count': 2,
#   'sentiment': -0.06813326478004456,
#   'neg_sentiment': 0.5},
#  '2021-05-07': {'edit_count': 1,
#   'sentiment': 0.7807150483131409,
#   'neg_sentiment': 0.0},
#  '2021-05-09': {'edit_count': 3,
#   'sentiment': -0.9981513420740763,
#   'neg_sentiment': 1.0},
#  '2021-05-11': {'edit_count': 2,
#   'sentiment': 0.9083044528961182,
#   'neg_sentiment': 0.0},
#  '2021-05-13': {'edit_count': 2,
#   'sentiment': -0.0276830792427063,
#   'neg_sentiment': 0.5},
#  '2021-05-14': {'edit_count': 2,
#   'sentiment': -0.9960139095783234,
#   'neg_sentiment': 1.0},
#  '2021-05-15': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-05-17': {'edit_count': 1,
#   'sentiment': -0.9972007274627686,
#   'neg_sentiment': 1.0},
#  '2021-05-18': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-05-21': {'edit_count': 2,
#   'sentiment': -0.992324709892273,
#   'neg_sentiment': 1.0},
#  '2021-05-22': {'edit_count': 2,
#   'sentiment': 0.007999211549758911,
#   'neg_sentiment': 0.5},
#  '2021-05-23': {'edit_count': 1,
#   'sentiment': -0.98943030834198,
#   'neg_sentiment': 1.0},
#  '2021-05-24': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-05-28': {'edit_count': 1,
#   'sentiment': 0.9964371919631958,
#   'neg_sentiment': 0.0},
#  '2021-05-31': {'edit_count': 2,
#   'sentiment': -0.0045268237590789795,
#   'neg_sentiment': 0.5},
#  '2021-06-01': {'edit_count': 1,
#   'sentiment': -0.9966766834259033,
#   'neg_sentiment': 1.0},
#  '2021-06-09': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-06-10': {'edit_count': 2,
#   'sentiment': -0.9937138855457306,
#   'neg_sentiment': 1.0},
#  '2021-06-14': {'edit_count': 1,
#   'sentiment': -0.999257504940033,
#   'neg_sentiment': 1.0},
#  '2021-06-22': {'edit_count': 2,
#   'sentiment': -0.9958315193653107,
#   'neg_sentiment': 1.0},
#  '2021-06-23': {'edit_count': 1,
#   'sentiment': -0.9954180717468262,
#   'neg_sentiment': 1.0},
#  '2021-06-25': {'edit_count': 3,
#   'sentiment': -0.33189111948013306,
#   'neg_sentiment': 0.6666666666666666},
#  '2021-07-05': {'edit_count': 2,
#   'sentiment': 0.9754540920257568,
#   'neg_sentiment': 0.0},
#  '2021-07-07': {'edit_count': 5,
#   'sentiment': 0.20674598217010498,
#   'neg_sentiment': 0.4},
#  '2021-07-08': {'edit_count': 2,
#   'sentiment': -0.8259581029415131,
#   'neg_sentiment': 1.0},
#  '2021-07-09': {'edit_count': 9,
#   'sentiment': -0.5473893019888136,
#   'neg_sentiment': 0.7777777777777778},
#  '2021-07-10': {'edit_count': 5,
#   'sentiment': -0.6591506958007812,
#   'neg_sentiment': 0.8},
#  '2021-07-11': {'edit_count': 3,
#   'sentiment': -0.41692566871643066,
#   'neg_sentiment': 0.6666666666666666},
#  '2021-07-14': {'edit_count': 4,
#   'sentiment': 0.02081550657749176,
#   'neg_sentiment': 0.5},
#  '2021-07-22': {'edit_count': 1,
#   'sentiment': -0.974304735660553,
#   'neg_sentiment': 1.0},
#  '2021-07-23': {'edit_count': 2,
#   'sentiment': -0.9671557545661926,
#   'neg_sentiment': 1.0},
#  '2021-07-26': {'edit_count': 1,
#   'sentiment': 0.8066481351852417,
#   'neg_sentiment': 0.0},
#  '2021-07-27': {'edit_count': 2,
#   'sentiment': -0.9747730493545532,
#   'neg_sentiment': 1.0},
#  '2021-08-05': {'edit_count': 29,
#   'sentiment': -0.02313515646704312,
#   'neg_sentiment': 0.5172413793103449},
#  '2021-08-06': {'edit_count': 4,
#   'sentiment': 0.5516876727342606,
#   'neg_sentiment': 0.25},
#  '2021-08-07': {'edit_count': 1,
#   'sentiment': -0.8806391358375549,
#   'neg_sentiment': 1.0},
#  '2021-08-08': {'edit_count': 2,
#   'sentiment': -0.12559986114501953,
#   'neg_sentiment': 0.5},
#  '2021-08-10': {'edit_count': 2,
#   'sentiment': -0.1252760887145996,
#   'neg_sentiment': 0.5},
#  '2021-08-11': {'edit_count': 4,
#   'sentiment': -0.9990681558847427,
#   'neg_sentiment': 1.0},
#  '2021-08-12': {'edit_count': 3,
#   'sentiment': -0.32306842009226483,
#   'neg_sentiment': 0.6666666666666666},
#  '2021-08-13': {'edit_count': 6,
#   'sentiment': -0.9862063825130463,
#   'neg_sentiment': 1.0},
#  '2021-08-14': {'edit_count': 4,
#   'sentiment': -0.4992019981145859,
#   'neg_sentiment': 0.75},
#  '2021-08-15': {'edit_count': 2,
#   'sentiment': -0.9991577565670013,
#   'neg_sentiment': 1.0},
#  '2021-08-17': {'edit_count': 1,
#   'sentiment': 0.8490421175956726,
#   'neg_sentiment': 0.0},
#  '2021-08-19': {'edit_count': 1,
#   'sentiment': 0.6681355834007263,
#   'neg_sentiment': 0.0},
#  '2021-08-20': {'edit_count': 3,
#   'sentiment': -0.9766223231951395,
#   'neg_sentiment': 1.0},
#  '2021-08-23': {'edit_count': 5,
#   'sentiment': -0.9778792500495911,
#   'neg_sentiment': 1.0},
#  '2021-08-24': {'edit_count': 1,
#   'sentiment': 0.9986400008201599,
#   'neg_sentiment': 0.0},
#  '2021-08-27': {'edit_count': 3,
#   'sentiment': -0.9902715484301249,
#   'neg_sentiment': 1.0},
#  '2021-08-28': {'edit_count': 1,
#   'sentiment': -0.9990730285644531,
#   'neg_sentiment': 1.0},
#  '2021-08-29': {'edit_count': 2,
#   'sentiment': -0.03012719750404358,
#   'neg_sentiment': 0.5},
#  '2021-08-30': {'edit_count': 1,
#   'sentiment': 0.9997586607933044,
#   'neg_sentiment': 0.0},
#  '2021-09-01': {'edit_count': 1,
#   'sentiment': -0.9927622675895691,
#   'neg_sentiment': 1.0},
#  '2021-09-02': {'edit_count': 3,
#   'sentiment': 0.8144076466560364,
#   'neg_sentiment': 0.0},
#  '2021-09-03': {'edit_count': 3,
#   'sentiment': 0.8319657246271769,
#   'neg_sentiment': 0.0},
#  '2021-09-08': {'edit_count': 1,
#   'sentiment': -0.9831823110580444,
#   'neg_sentiment': 1.0},
#  '2021-09-10': {'edit_count': 1,
#   'sentiment': -0.9973128437995911,
#   'neg_sentiment': 1.0},
#  '2021-09-11': {'edit_count': 2,
#   'sentiment': -0.9915521740913391,
#   'neg_sentiment': 1.0},
#  '2021-09-13': {'edit_count': 1,
#   'sentiment': -0.9977189898490906,
#   'neg_sentiment': 1.0},
#  '2021-09-14': {'edit_count': 1,
#   'sentiment': -0.9877215027809143,
#   'neg_sentiment': 1.0},
#  '2021-09-15': {'edit_count': 1,
#   'sentiment': -0.8307504057884216,
#   'neg_sentiment': 1.0},
#  '2021-09-19': {'edit_count': 2,
#   'sentiment': -0.9914396405220032,
#   'neg_sentiment': 1.0},
#  '2021-09-20': {'edit_count': 4,
#   'sentiment': -0.0563368946313858,
#   'neg_sentiment': 0.5},
#  '2021-09-23': {'edit_count': 2,
#   'sentiment': -0.12584355473518372,
#   'neg_sentiment': 0.5},
#  '2021-09-24': {'edit_count': 3,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-09-26': {'edit_count': 1,
#   'sentiment': 0.8066481351852417,
#   'neg_sentiment': 0.0},
#  '2021-09-27': {'edit_count': 2,
#   'sentiment': -0.9955781996250153,
#   'neg_sentiment': 1.0},
#  '2021-09-28': {'edit_count': 5,
#   'sentiment': 0.5479763865470886,
#   'neg_sentiment': 0.2},
#  '2021-09-29': {'edit_count': 9,
#   'sentiment': 0.021376437611050077,
#   'neg_sentiment': 0.4444444444444444},
#  '2021-09-30': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-10-03': {'edit_count': 1,
#   'sentiment': -0.9826617240905762,
#   'neg_sentiment': 1.0},
#  '2021-10-04': {'edit_count': 2,
#   'sentiment': -0.022235870361328125,
#   'neg_sentiment': 0.5},
#  '2021-10-06': {'edit_count': 1,
#   'sentiment': -0.9948210716247559,
#   'neg_sentiment': 1.0},
#  '2021-10-08': {'edit_count': 1,
#   'sentiment': -0.994492769241333,
#   'neg_sentiment': 1.0},
#  '2021-10-09': {'edit_count': 1,
#   'sentiment': -0.9008830785751343,
#   'neg_sentiment': 1.0},
#  '2021-10-11': {'edit_count': 1,
#   'sentiment': 0.7957471609115601,
#   'neg_sentiment': 0.0},
#  '2021-10-18': {'edit_count': 1,
#   'sentiment': -0.9591113924980164,
#   'neg_sentiment': 1.0},
#  '2021-10-28': {'edit_count': 2,
#   'sentiment': 0.00043073296546936035,
#   'neg_sentiment': 0.5},
#  '2021-10-29': {'edit_count': 2,
#   'sentiment': -0.009146898984909058,
#   'neg_sentiment': 0.5},
#  '2021-11-02': {'edit_count': 1,
#   'sentiment': -0.9993627667427063,
#   'neg_sentiment': 1.0},
#  '2021-11-09': {'edit_count': 1,
#   'sentiment': 0.9963186979293823,
#   'neg_sentiment': 0.0},
#  '2021-11-10': {'edit_count': 1,
#   'sentiment': -0.9521404504776001,
#   'neg_sentiment': 1.0},
#  '2021-11-12': {'edit_count': 1,
#   'sentiment': -0.9973095655441284,
#   'neg_sentiment': 1.0},
#  '2021-11-15': {'edit_count': 1,
#   'sentiment': 0.8066481351852417,
#   'neg_sentiment': 0.0},
#  '2021-11-17': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-11-26': {'edit_count': 1,
#   'sentiment': 0.9804309010505676,
#   'neg_sentiment': 0.0},
#  '2021-11-27': {'edit_count': 1,
#   'sentiment': -0.9216547012329102,
#   'neg_sentiment': 1.0},
#  '2021-11-28': {'edit_count': 1,
#   'sentiment': -0.9957720637321472,
#   'neg_sentiment': 1.0},
#  '2021-12-06': {'edit_count': 2,
#   'sentiment': -0.9976881146430969,
#   'neg_sentiment': 1.0},
#  '2021-12-07': {'edit_count': 2,
#   'sentiment': -0.006852656602859497,
#   'neg_sentiment': 0.5},
#  '2021-12-08': {'edit_count': 1,
#   'sentiment': -0.9807369709014893,
#   'neg_sentiment': 1.0},
#  '2021-12-24': {'edit_count': 1,
#   'sentiment': -0.9994571805000305,
#   'neg_sentiment': 1.0},
#  ...}

# %%
# Converting to Pandas dataframe from dictionary
edits_df = pd.DataFrame.from_dict(edits, orient="index")

# %%
edits_df
# Out:
#             edit_count  sentiment  neg_sentiment
# 2014-01-27           1  -0.998511       1.000000
# 2014-02-01           1  -0.997276       1.000000
# 2014-04-06           5   0.790979       0.000000
# 2014-04-09          24   0.646407       0.083333
# 2014-04-10           9  -0.361518       0.666667
# ...                ...        ...            ...
# 2025-08-25           1  -0.999620       1.000000
# 2025-08-29           3   0.253291       0.333333
# 2025-09-03           2  -0.022424       0.500000
# 2025-09-08           2   0.744423       0.000000
# 2025-09-15           2   0.748121       0.000000
#
# [1212 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# Extracting neg_sentiment and sentiment values
neg_sentiment_values = [edits[key]["neg_sentiment"] for key in edits]
sentiment_values = [edits[key]["sentiment"] for key in edits]

# Plotting histograms
plt.figure(figsize=(12, 6))

# Histogram for neg_sentiment
plt.subplot(1, 2, 1)
plt.hist(neg_sentiment_values, bins=10, color='red', alpha=0.7)
plt.title('Histogram of Negative Sentiment')
plt.xlabel('Negative Sentiment')
plt.ylabel('Frequency')

# Histogram for sentiment
plt.subplot(1, 2, 2)
plt.hist(sentiment_values, bins=10, color='blue', alpha=0.7)
plt.title('Histogram of Overall Sentiment')
plt.xlabel('Overall Sentiment')
plt.ylabel('Frequency')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
edits_df.index = pd.to_datetime(edits_df.index) # turning it from string to datetime obj

# %%
# Generating a date range from 2014-01-27
dates = pd.date_range(start="2014-01-27", end=datetime.today())

# %%
dates
# Out:
# DatetimeIndex(['2014-01-27', '2014-01-28', '2014-01-29', '2014-01-30',
#                '2014-01-31', '2014-02-01', '2014-02-02', '2014-02-03',
#                '2014-02-04', '2014-02-05',
#                ...
#                '2025-09-07', '2025-09-08', '2025-09-09', '2025-09-10',
#                '2025-09-11', '2025-09-12', '2025-09-13', '2025-09-14',
#                '2025-09-15', '2025-09-16'],
#               dtype='datetime64[ns]', length=4251, freq='D')

# %%
edits_df = edits_df.reindex(dates, fill_value = 0)

# %%
edits_df
# Out:
#             edit_count  sentiment  neg_sentiment
# 2014-01-27           1  -0.998511            1.0
# 2014-01-28           0   0.000000            0.0
# 2014-01-29           0   0.000000            0.0
# 2014-01-30           0   0.000000            0.0
# 2014-01-31           0   0.000000            0.0
# ...                ...        ...            ...
# 2025-09-12           0   0.000000            0.0
# 2025-09-13           0   0.000000            0.0
# 2025-09-14           0   0.000000            0.0
# 2025-09-15           2   0.748121            0.0
# 2025-09-16           0   0.000000            0.0
#
# [4251 rows x 3 columns]

# %%
#Creata a rollong avg for the sentiment
rolling_edits = edits_df.rolling(30).mean()

# %%
rolling_edits
# Out:
#             edit_count  sentiment  neg_sentiment
# 2014-01-27         NaN        NaN            NaN
# 2014-01-28         NaN        NaN            NaN
# 2014-01-29         NaN        NaN            NaN
# 2014-01-30         NaN        NaN            NaN
# 2014-01-31         NaN        NaN            NaN
# ...                ...        ...            ...
# 2025-09-12    0.266667  -0.000811       0.061111
# 2025-09-13    0.266667  -0.000811       0.061111
# 2025-09-14    0.266667  -0.000811       0.061111
# 2025-09-15    0.333333   0.024126       0.061111
# 2025-09-16    0.333333   0.024126       0.061111
#
# [4251 rows x 3 columns]

# %%
# Dropping rows with missing values
rolling_edits = rolling_edits.dropna()

# %%
rolling_edits
# Out:
#             edit_count  sentiment  neg_sentiment
# 2014-02-25    0.066667  -0.066526       0.066667
# 2014-02-26    0.033333  -0.033243       0.033333
# 2014-02-27    0.033333  -0.033243       0.033333
# 2014-02-28    0.033333  -0.033243       0.033333
# 2014-03-01    0.033333  -0.033243       0.033333
# ...                ...        ...            ...
# 2025-09-12    0.266667  -0.000811       0.061111
# 2025-09-13    0.266667  -0.000811       0.061111
# 2025-09-14    0.266667  -0.000811       0.061111
# 2025-09-15    0.333333   0.024126       0.061111
# 2025-09-16    0.333333   0.024126       0.061111
#
# [4222 rows x 3 columns]

# %%
# Saving the dataframe to a CSV file
rolling_edits.to_csv("Wikipedia_Edits.csv ")

# %%
# Getting the price history of ethereum
eth_ticker = yf.Ticker("ETH-USD")

# %%
# Fetching historical price data for Ethereum
eth = eth_ticker.history(period = "max")

# %%
eth
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2017-11-09 00:00:00+00:00   308.644989   329.451996   307.056000   320.884003
# 2017-11-10 00:00:00+00:00   320.670990   324.717987   294.541992   299.252991
# 2017-11-11 00:00:00+00:00   298.585999   319.453003   298.191986   314.681000
# 2017-11-12 00:00:00+00:00   314.690002   319.153015   298.513000   307.907990
# 2017-11-13 00:00:00+00:00   307.024994   328.415009   307.024994   316.716003
# ...                                ...          ...          ...          ...
# 2025-09-12 00:00:00+00:00  4461.479492  4734.273926  4453.284668  4715.246094
# 2025-09-13 00:00:00+00:00  4714.703613  4763.361328  4609.125488  4668.179688
# 2025-09-14 00:00:00+00:00  4668.171387  4690.642090  4581.847168  4609.597656
# 2025-09-15 00:00:00+00:00  4609.723145  4670.530273  4469.861328  4526.820312
# 2025-09-16 00:00:00+00:00  4525.424316  4535.958008  4433.892090  4495.479004
#
#                                 Volume  Dividends  Stock Splits
# Date
# 2017-11-09 00:00:00+00:00    893249984        0.0           0.0
# 2017-11-10 00:00:00+00:00    885985984        0.0           0.0
# 2017-11-11 00:00:00+00:00    842300992        0.0           0.0
# 2017-11-12 00:00:00+00:00   1613479936        0.0           0.0
# 2017-11-13 00:00:00+00:00   1041889984        0.0           0.0
# ...                                ...        ...           ...
# 2025-09-12 00:00:00+00:00  43839753626        0.0           0.0
# 2025-09-13 00:00:00+00:00  34843845977        0.0           0.0
# 2025-09-14 00:00:00+00:00  28394160275        0.0           0.0
# 2025-09-15 00:00:00+00:00  40224062009        0.0           0.0
# 2025-09-16 00:00:00+00:00  30325778432        0.0           0.0
#
# [2869 rows x 7 columns]

# %%
# Convert index to datetime and remove timezone information
eth.index = pd.to_datetime(eth.index)
eth.index = eth.index.tz_localize(None)

# %%
# Deleting columns
del eth["Dividends"]
del eth["Stock Splits"]

# %%
# Plotting Ethereum closing price trends over time
eth.plot.line(y="Close", use_index=True, title="Visualization of Ethereum price trends")
# Out:
# <Axes: title={'center': 'Visualization of Ethereum price trends'}, xlabel='Date'>

# %%
# Reading the Wikipedia edits data from a CSV file into a DataFrame
wiki = pd.read_csv("C:/Users/sanja/OneDrive/Documents/UTD/Prgrmg for DS 6340/Project/Wikipedia_Edits.csv ", index_col=0, parse_dates=True)

# %%
wiki
# Out:
#             edit_count  sentiment  neg_sentiment
# 2014-02-25    0.066667  -0.066526       0.066667
# 2014-02-26    0.033333  -0.033243       0.033333
# 2014-02-27    0.033333  -0.033243       0.033333
# 2014-02-28    0.033333  -0.033243       0.033333
# 2014-03-01    0.033333  -0.033243       0.033333
# ...                ...        ...            ...
# 2025-09-11    0.266667  -0.000811       0.061111
# 2025-09-12    0.266667  -0.000811       0.061111
# 2025-09-13    0.266667  -0.000811       0.061111
# 2025-09-14    0.266667  -0.000811       0.061111
# 2025-09-15    0.333333   0.024126       0.061111
#
# [4221 rows x 3 columns]

# %%
# Merging the Ethereum price data with the Wikipedia edits data based on their index (date)
eth = eth.merge(wiki, left_index=True, right_index=True)

# %%
eth
# Out:
#                    Open         High          Low        Close       Volume  \
# 2017-11-09   308.644989   329.451996   307.056000   320.884003    893249984
# 2017-11-10   320.670990   324.717987   294.541992   299.252991    885985984
# 2017-11-11   298.585999   319.453003   298.191986   314.681000    842300992
# 2017-11-12   314.690002   319.153015   298.513000   307.907990   1613479936
# 2017-11-13   307.024994   328.415009   307.024994   316.716003   1041889984
# ...                 ...          ...          ...          ...          ...
# 2025-09-11  4349.200195  4471.698730  4339.716797  4461.233398  35959212991
# 2025-09-12  4461.479492  4734.273926  4453.284668  4715.246094  43839753626
# 2025-09-13  4714.703613  4763.361328  4609.125488  4668.179688  34843845977
# 2025-09-14  4668.171387  4690.642090  4581.847168  4609.597656  28394160275
# 2025-09-15  4609.723145  4670.530273  4469.861328  4526.820312  40224062009
#
#             edit_count  sentiment  neg_sentiment
# 2017-11-09    0.900000  -0.144123       0.261111
# 2017-11-10    0.966667  -0.177429       0.294444
# 2017-11-11    0.966667  -0.177429       0.294444
# 2017-11-12    0.966667  -0.177429       0.294444
# 2017-11-13    1.100000  -0.209260       0.327778
# ...                ...        ...            ...
# 2025-09-11    0.266667  -0.000811       0.061111
# 2025-09-12    0.266667  -0.000811       0.061111
# 2025-09-13    0.266667  -0.000811       0.061111
# 2025-09-14    0.266667  -0.000811       0.061111
# 2025-09-15    0.333333   0.024126       0.061111
#
# [2868 rows x 8 columns]

# %%
eth["Tomorrow"] = eth["Close"].shift(-1)

# %%
eth["Target"] = (eth["Tomorrow"] > eth["Close"]).astype(int)

# %%
eth["Target"].value_counts()
# Out:
# Target
# 1    1472
# 0    1396
# Name: count, dtype: int64

# %%
model = RandomForestClassifier(n_estimators=100, min_samples_split=50, random_state=1)
train = eth.iloc[:-200]
test = eth[-200:]
predictors = ["Close", "Volume", "Open", "High", "Low", "edit_count", "sentiment", "neg_sentiment"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=50, random_state=1)

# %%
preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["Target"], preds) # Baseline precicsion score
# Out:
# 0.5242718446601942

# %%
#  Function to make predictions using a trained model.
def predict(train, test, predictors, model):
  model.fit(train[predictors], train["Target"])
  preds = model.predict(test[predictors])
  preds = pd.Series(preds, index=test.index)
  combined = pd.concat([test["Target"], preds], axis=1)
  return combined

# %%
# Function to perform backtesting on a given dataset using a trained model.
def  backtest(data, model, predictors, start=1095, step=150):
  all_predictions = []

  for i in range(start, data.shape[0], step):
    train = data.iloc[0:i].copy()
    test = data.iloc[i:(i+step)].copy()
    predictions = predict(train,test, predictors, model)
    all_predictions.append(predictions)

    return pd.concat(all_predictions)

# %%
model = XGBClassifier(random_state=1, learning_rate=.1, n_estimators=200)
Predictions = backtest(eth, model, predictors)

# %%
Predictions.rename(columns={0: 'predictions'}, inplace=True)

# %%
precision_score(Predictions["Target"], Predictions["predictions"])
# Out:
# 0.625

# %%
Predictions
# Out:
#             Target  predictions
# 2020-11-08       0            1
# 2020-11-09       1            1
# 2020-11-10       1            0
# 2020-11-11       0            0
# 2020-11-12       1            0
# ...            ...          ...
# 2021-04-02       0            0
# 2021-04-03       1            0
# 2021-04-04       1            0
# 2021-04-05       1            0
# 2021-04-06       0            0
#
# [150 rows x 2 columns]
